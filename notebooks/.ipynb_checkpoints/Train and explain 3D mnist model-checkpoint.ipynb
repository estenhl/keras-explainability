# %%
import h5py
import os
import matplotlib.pyplot as plt
import numpy as np

data_path = os.path.join(os.path.expanduser('~'), 'data', '3d-mnist', 
                         'full_dataset_vectors.h5')

assert os.path.isfile(data_path), \
    'Download the 3d-mnist data from https://www.kaggle.com/daavoo/3d-mnist'

with h5py.File(data_path, 'r') as f:
    train_X = np.reshape(f["X_train"][:], (-1, 16, 16, 16, 1))
    train_y = f["y_train"][:]    
    test_X = np.reshape(f["X_test"][:]  , (-1, 16, 16, 16, 1))
    test_y = f["y_test"][:]

train_X = train_X[:,::-1,:,:]
test_X = test_X[:,::-1,:,:]

def onehot(values: np.ndarray) -> np.ndarray:
    encoded = np.zeros((len(values), 10))

    for i in range(len(values)):
        encoded[i,values[i]] = 1

    return encoded

train_y = onehot(train_y)
test_y = onehot(test_y)

for i in range(5):
    fig, ax = plt.subplots(4, 4)
    fig.suptitle(str(np.argmax(train_y[i])))
    ax = ax.ravel()

    for j in range(16):
        ax[j].imshow(train_X[i,:,:,j], cmap='Greys')
        ax[j].axis('off')

    plt.show()

# %%
from tensorflow.keras import Model
from tensorflow.keras.layers import Activation, BatchNormalization, Conv3D, Dense, \
                                    Dropout, Flatten, \
                                    GlobalAveragePooling3D, Input, \
                                    MaxPooling3D
from tensorflow.keras.regularizers import l2

inputs = Input((16, 16, 16, 1), name='inputs')

x = inputs

kernel = (3, 3, 3)
dropout = 0.3
weight_decay = 1e-3
regularizer = l2(weight_decay)

x = Conv3D(32, kernel, padding='SAME', activation=None, 
           kernel_regularizer=regularizer, name='conv1')(x)
x = BatchNormalization(name='norm1')(x)
x = Activation('relu')(x)
x = Conv3D(32, kernel, padding='SAME', activation=None, 
           kernel_regularizer=regularizer, name='conv2')(x)
x = BatchNormalization(name='norm2')(x)
x = Activation('relu')(x)
x = MaxPooling3D((2, 2, 2), name='pool1')(x)
x = Conv3D(64, kernel, padding='SAME', activation=None, 
           kernel_regularizer=regularizer, name='conv3')(x)
x = BatchNormalization(name='norm3')(x)
x = Activation('relu')(x)
x = Conv3D(64, kernel, padding='SAME', activation=None, 
           kernel_regularizer=regularizer, name='conv4')(x)
x = BatchNormalization(name='norm4')(x)
x = Activation('relu')(x)
x = MaxPooling3D((2, 2, 2), name='pool2')(x)
x = Conv3D(128, kernel, padding='SAME', activation=None, 
           kernel_regularizer=regularizer, name='conv5')(x)
x = BatchNormalization(name='norm5')(x)
x = Activation('relu')(x)
x = Conv3D(128, kernel, padding='SAME', activation=None, 
           kernel_regularizer=regularizer, name='conv6')(x)
x = BatchNormalization(name='norm6')(x)
x = MaxPooling3D((2, 2, 2), name='pool3')(x)
x = Conv3D(256, kernel, padding='SAME', activation=None, 
           kernel_regularizer=regularizer, name='conv7')(x)
x = BatchNormalization(name='norm7')(x)
x = Activation('relu')(x)
x = Conv3D(256, kernel, padding='SAME', activation=None, 
           kernel_regularizer=regularizer, name='conv8')(x)
x = BatchNormalization(name='norm8')(x)
x = Activation('relu')(x)
x = GlobalAveragePooling3D(name='pool4')(x)
x = Dropout(dropout)(x)
x = Dense(10, kernel_regularizer=regularizer, activation=None, name='dense')(x)
x = BatchNormalization(name='norm9')(x)
x = Activation('relu')(x)
x = Dropout(dropout)(x)
x = Dense(10, activation='softmax', name='preds')(x)

model = Model(inputs, x)
model.summary()
# Out:
# 2022-03-13 11:28:52.233368: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-03-13 11:28:52.239357: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-03-13 11:28:52.239528: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# inputs (InputLayer)          [(None, 16, 16, 16, 1)]   0
# _________________________________________________________________
# conv1 (Conv3D)               (None, 16, 16, 16, 32)    896
# _________________________________________________________________
# norm1 (BatchNormalization)   (None, 16, 16, 16, 32)    128
# _________________________________________________________________
# activation (Activation)      (None, 16, 16, 16, 32)    0
# _________________________________________________________________
# conv2 (Conv3D)               (None, 16, 16, 16, 32)    27680
# _________________________________________________________________
# norm2 (BatchNormalization)   (None, 16, 16, 16, 32)    128
# _________________________________________________________________
# activation_1 (Activation)    (None, 16, 16, 16, 32)    0
# _________________________________________________________________
# pool1 (MaxPooling3D)         (None, 8, 8, 8, 32)       0
# _________________________________________________________________
# conv3 (Conv3D)               (None, 8, 8, 8, 64)       55360
# _________________________________________________________________
# norm3 (BatchNormalization)   (None, 8, 8, 8, 64)       256
# _________________________________________________________________
# activation_2 (Activation)    (None, 8, 8, 8, 64)       0
# _________________________________________________________________
# conv4 (Conv3D)               (None, 8, 8, 8, 64)       110656
# _________________________________________________________________
# norm4 (BatchNormalization)   (None, 8, 8, 8, 64)       256
# _________________________________________________________________
# activation_3 (Activation)    (None, 8, 8, 8, 64)       0
# _________________________________________________________________
# pool2 (MaxPooling3D)         (None, 4, 4, 4, 64)       0
# _________________________________________________________________
# conv5 (Conv3D)               (None, 4, 4, 4, 128)      221312
# _________________________________________________________________
# norm5 (BatchNormalization)   (None, 4, 4, 4, 128)      512
# _________________________________________________________________
# activation_4 (Activation)    (None, 4, 4, 4, 128)      0
# _________________________________________________________________
# conv6 (Conv3D)               (None, 4, 4, 4, 128)      442496
# _________________________________________________________________
# norm6 (BatchNormalization)   (None, 4, 4, 4, 128)      512
# _________________________________________________________________
# pool3 (MaxPooling3D)         (None, 2, 2, 2, 128)      0
# _________________________________________________________________
# conv7 (Conv3D)               (None, 2, 2, 2, 256)      884992
# _________________________________________________________________
# norm7 (BatchNormalization)   (None, 2, 2, 2, 256)      1024
# _________________________________________________________________
# activation_5 (Activation)    (None, 2, 2, 2, 256)      0
# _________________________________________________________________
# conv8 (Conv3D)               (None, 2, 2, 2, 256)      1769728
# _________________________________________________________________
# norm8 (BatchNormalization)   (None, 2, 2, 2, 256)      1024
# _________________________________________________________________
# activation_6 (Activation)    (None, 2, 2, 2, 256)      0
# _________________________________________________________________
# pool4 (GlobalAveragePooling3 (None, 256)               0
# _________________________________________________________________
# dropout (Dropout)            (None, 256)               0
# _________________________________________________________________
# dense (Dense)                (None, 10)                2570
# _________________________________________________________________
# norm9 (BatchNormalization)   (None, 10)                40
# _________________________________________________________________
# activation_7 (Activation)    (None, 10)                0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 10)                0
# _________________________________________________________________
# preds (Dense)                (None, 10)                110
# =================================================================
# Total params: 3,519,680
# Trainable params: 3,517,740
# Non-trainable params: 1,940
# _________________________________________________________________
# 2022-03-13 11:28:52.240463: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-03-13 11:28:52.241043: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-03-13 11:28:52.241240: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-03-13 11:28:52.241373: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-03-13 11:28:52.642971: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-03-13 11:28:52.643135: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-03-13 11:28:52.643270: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-03-13 11:28:52.643389: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1510] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 11069 MB memory:  -> device: 0, name: NVIDIA TITAN X (Pascal), pci bus id: 0000:01:00.0, compute capability: 6.1

# %%
from tensorflow.keras.callbacks import ReduceLROnPlateau
from tensorflow.keras.optimizers import Adam

model.compile(loss='categorical_crossentropy', optimizer=Adam(1e-3),
              metrics=['accuracy'])

callbacks = [
    ReduceLROnPlateau(
        monitor="loss",
        factor=0.1,
        patience=5,
        verbose=1
    )
]

model.fit(train_X, train_y, 
          validation_data=(test_X, test_y), 
          epochs=100, 
          batch_size=32, 
          shuffle=True,
          callbacks=callbacks)
# Out:
# 2022-03-13 11:28:53.325602: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:185] None of the MLIR Optimization Passes are enabled (registered 2)
# Epoch 1/100
# 2022-03-13 11:28:54.784579: I tensorflow/stream_executor/cuda/cuda_dnn.cc:369] Loaded cuDNN version 8100
# 2022-03-13 11:28:54.975813: W tensorflow/stream_executor/gpu/asm_compiler.cc:113] *** WARNING *** You are using ptxas 9.1.108, which is older than 9.2.88. ptxas 9.x before 9.2.88 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You do not need to update to CUDA 9.2.88; cherry-picking the ptxas binary is sufficient.
# 313/313 [==============================] - 9s 22ms/step - loss: 2.5258 - accuracy: 0.2979 - val_loss: 2.5750 - val_accuracy: 0.1750
# Epoch 2/100
# 313/313 [==============================] - 7s 21ms/step - loss: 1.9296 - accuracy: 0.4363 - val_loss: 1.7746 - val_accuracy: 0.5220
# Epoch 3/100
# 313/313 [==============================] - 7s 21ms/step - loss: 1.7686 - accuracy: 0.4774 - val_loss: 1.5906 - val_accuracy: 0.5640
# Epoch 4/100
# 313/313 [==============================] - 7s 21ms/step - loss: 1.6751 - accuracy: 0.5056 - val_loss: 1.7453 - val_accuracy: 0.4760
# Epoch 5/100
# 313/313 [==============================] - 7s 21ms/step - loss: 1.6413 - accuracy: 0.5308 - val_loss: 1.3895 - val_accuracy: 0.6055
# Epoch 6/100
# 313/313 [==============================] - 7s 21ms/step - loss: 1.5939 - accuracy: 0.5569 - val_loss: 1.6742 - val_accuracy: 0.5590
# Epoch 7/100
# 313/313 [==============================] - 7s 22ms/step - loss: 1.5411 - accuracy: 0.5734 - val_loss: 1.4153 - val_accuracy: 0.6260
# Epoch 8/100
# 313/313 [==============================] - 7s 21ms/step - loss: 1.5125 - accuracy: 0.5863 - val_loss: 1.5552 - val_accuracy: 0.5790
# Epoch 9/100
# 313/313 [==============================] - 7s 22ms/step - loss: 1.4672 - accuracy: 0.6070 - val_loss: 1.3904 - val_accuracy: 0.6370
# Epoch 10/100
# 313/313 [==============================] - 7s 22ms/step - loss: 1.4460 - accuracy: 0.6179 - val_loss: 1.4053 - val_accuracy: 0.6345
# Epoch 11/100
# 313/313 [==============================] - 7s 22ms/step - loss: 1.4139 - accuracy: 0.6321 - val_loss: 1.2606 - val_accuracy: 0.6830
# Epoch 12/100
# 313/313 [==============================] - 7s 22ms/step - loss: 1.3715 - accuracy: 0.6461 - val_loss: 1.3449 - val_accuracy: 0.6575
# Epoch 13/100
# 313/313 [==============================] - 7s 22ms/step - loss: 1.3345 - accuracy: 0.6520 - val_loss: 1.2558 - val_accuracy: 0.6900
# Epoch 14/100
# 313/313 [==============================] - 7s 23ms/step - loss: 1.3097 - accuracy: 0.6619 - val_loss: 1.3069 - val_accuracy: 0.6455
# Epoch 15/100
# 313/313 [==============================] - 7s 22ms/step - loss: 1.3085 - accuracy: 0.6731 - val_loss: 1.1779 - val_accuracy: 0.7160
# Epoch 16/100
# 313/313 [==============================] - 7s 22ms/step - loss: 1.2756 - accuracy: 0.6777 - val_loss: 1.2727 - val_accuracy: 0.6820
# Epoch 17/100
# 313/313 [==============================] - 7s 23ms/step - loss: 1.2522 - accuracy: 0.6895 - val_loss: 1.1581 - val_accuracy: 0.7225
# Epoch 18/100
# 313/313 [==============================] - 7s 22ms/step - loss: 1.2267 - accuracy: 0.6941 - val_loss: 1.1409 - val_accuracy: 0.7330
# Epoch 19/100
# 313/313 [==============================] - 7s 23ms/step - loss: 1.2082 - accuracy: 0.7005 - val_loss: 1.3110 - val_accuracy: 0.6705
# Epoch 20/100
# 313/313 [==============================] - 7s 23ms/step - loss: 1.1654 - accuracy: 0.7185 - val_loss: 1.1875 - val_accuracy: 0.7100
# Epoch 21/100
# 313/313 [==============================] - 7s 23ms/step - loss: 1.1660 - accuracy: 0.7165 - val_loss: 1.1721 - val_accuracy: 0.7020
# Epoch 22/100
# 313/313 [==============================] - 7s 23ms/step - loss: 1.1516 - accuracy: 0.7206 - val_loss: 1.0202 - val_accuracy: 0.7610
# Epoch 23/100
# 313/313 [==============================] - 7s 22ms/step - loss: 1.0936 - accuracy: 0.7445 - val_loss: 1.2950 - val_accuracy: 0.6885
# Epoch 24/100
# 313/313 [==============================] - 7s 23ms/step - loss: 1.1003 - accuracy: 0.7362 - val_loss: 1.0969 - val_accuracy: 0.7575
# Epoch 25/100
# 313/313 [==============================] - 7s 23ms/step - loss: 1.0729 - accuracy: 0.7506 - val_loss: 1.0158 - val_accuracy: 0.7670
# Epoch 26/100
# 313/313 [==============================] - 7s 23ms/step - loss: 1.0779 - accuracy: 0.7525 - val_loss: 1.0354 - val_accuracy: 0.7695
# Epoch 27/100
# 313/313 [==============================] - 7s 23ms/step - loss: 1.0678 - accuracy: 0.7591 - val_loss: 1.1731 - val_accuracy: 0.7165
# Epoch 28/100
# 313/313 [==============================] - 7s 23ms/step - loss: 1.0246 - accuracy: 0.7683 - val_loss: 1.0798 - val_accuracy: 0.7575
# Epoch 29/100
# 313/313 [==============================] - 7s 23ms/step - loss: 1.0161 - accuracy: 0.7756 - val_loss: 1.0332 - val_accuracy: 0.7630
# Epoch 30/100
# 313/313 [==============================] - 7s 23ms/step - loss: 1.0271 - accuracy: 0.7684 - val_loss: 0.9862 - val_accuracy: 0.7880
# Epoch 31/100
# 313/313 [==============================] - 7s 22ms/step - loss: 1.0070 - accuracy: 0.7710 - val_loss: 1.2485 - val_accuracy: 0.7015
# Epoch 32/100
# 313/313 [==============================] - 7s 24ms/step - loss: 0.9681 - accuracy: 0.7884 - val_loss: 1.0875 - val_accuracy: 0.7665
# Epoch 33/100
# 313/313 [==============================] - 7s 22ms/step - loss: 0.9890 - accuracy: 0.7855 - val_loss: 1.1651 - val_accuracy: 0.7565
# Epoch 34/100
# 313/313 [==============================] - 7s 23ms/step - loss: 0.9701 - accuracy: 0.7870 - val_loss: 1.3269 - val_accuracy: 0.7295
# Epoch 35/100
# 313/313 [==============================] - 7s 23ms/step - loss: 0.9479 - accuracy: 0.7973 - val_loss: 1.1289 - val_accuracy: 0.7645
# Epoch 36/100
# 313/313 [==============================] - 7s 22ms/step - loss: 0.9211 - accuracy: 0.8066 - val_loss: 1.0640 - val_accuracy: 0.7645
# Epoch 37/100
# 313/313 [==============================] - 7s 23ms/step - loss: 0.9565 - accuracy: 0.7955 - val_loss: 1.0385 - val_accuracy: 0.7810
# Epoch 38/100
# 313/313 [==============================] - 7s 22ms/step - loss: 0.9570 - accuracy: 0.7998 - val_loss: 1.2368 - val_accuracy: 0.7385
# Epoch 39/100
# 313/313 [==============================] - 7s 22ms/step - loss: 0.9221 - accuracy: 0.8089 - val_loss: 1.4529 - val_accuracy: 0.7125
# Epoch 40/100
# 313/313 [==============================] - 7s 22ms/step - loss: 0.9401 - accuracy: 0.8018 - val_loss: 1.1053 - val_accuracy: 0.7645
# Epoch 41/100
# 313/313 [==============================] - 7s 22ms/step - loss: 0.9351 - accuracy: 0.8089 - val_loss: 1.1329 - val_accuracy: 0.7575
#
# Epoch 00041: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# Epoch 42/100
# 313/313 [==============================] - 7s 23ms/step - loss: 0.7890 - accuracy: 0.8570 - val_loss: 0.9380 - val_accuracy: 0.8220
# Epoch 43/100
# 313/313 [==============================] - 7s 23ms/step - loss: 0.7205 - accuracy: 0.8739 - val_loss: 0.9488 - val_accuracy: 0.8210
# Epoch 44/100
# 313/313 [==============================] - 7s 22ms/step - loss: 0.6895 - accuracy: 0.8804 - val_loss: 0.9574 - val_accuracy: 0.8215
# Epoch 45/100
# 313/313 [==============================] - 7s 22ms/step - loss: 0.6599 - accuracy: 0.8927 - val_loss: 0.9591 - val_accuracy: 0.8235
# Epoch 46/100
# 313/313 [==============================] - 7s 22ms/step - loss: 0.6410 - accuracy: 0.8904 - val_loss: 0.9578 - val_accuracy: 0.8240
# Epoch 47/100
# 313/313 [==============================] - 7s 22ms/step - loss: 0.6285 - accuracy: 0.8945 - val_loss: 0.9717 - val_accuracy: 0.8225
# Epoch 48/100
# 313/313 [==============================] - 7s 23ms/step - loss: 0.6097 - accuracy: 0.8965 - val_loss: 0.9693 - val_accuracy: 0.8245
# Epoch 49/100
# 313/313 [==============================] - 7s 23ms/step - loss: 0.5790 - accuracy: 0.9046 - val_loss: 0.9704 - val_accuracy: 0.8190
# Epoch 50/100
# 313/313 [==============================] - 7s 22ms/step - loss: 0.5659 - accuracy: 0.9060 - val_loss: 0.9904 - val_accuracy: 0.8205
# Epoch 51/100
# 313/313 [==============================] - 7s 22ms/step - loss: 0.5618 - accuracy: 0.9058 - val_loss: 1.0114 - val_accuracy: 0.8220
# Epoch 52/100
# 313/313 [==============================] - 7s 23ms/step - loss: 0.5280 - accuracy: 0.9172 - val_loss: 0.9974 - val_accuracy: 0.8215
# Epoch 53/100
# 313/313 [==============================] - 7s 23ms/step - loss: 0.5386 - accuracy: 0.9099 - val_loss: 1.0018 - val_accuracy: 0.8255
# Epoch 54/100
# 313/313 [==============================] - 7s 22ms/step - loss: 0.5159 - accuracy: 0.9160 - val_loss: 1.0188 - val_accuracy: 0.8210
# Epoch 55/100
# 313/313 [==============================] - 7s 23ms/step - loss: 0.5114 - accuracy: 0.9162 - val_loss: 0.9968 - val_accuracy: 0.8305
# Epoch 56/100
# 313/313 [==============================] - 7s 22ms/step - loss: 0.5053 - accuracy: 0.9188 - val_loss: 1.0208 - val_accuracy: 0.8255
# Epoch 57/100
# 313/313 [==============================] - 7s 23ms/step - loss: 0.4943 - accuracy: 0.9176 - val_loss: 1.0379 - val_accuracy: 0.8190
# Epoch 58/100
# 313/313 [==============================] - 7s 22ms/step - loss: 0.4922 - accuracy: 0.9149 - val_loss: 1.0358 - val_accuracy: 0.8245
# Epoch 59/100
# 313/313 [==============================] - 7s 22ms/step - loss: 0.4748 - accuracy: 0.9220 - val_loss: 1.0359 - val_accuracy: 0.8190
# Epoch 60/100
# 313/313 [==============================] - 7s 23ms/step - loss: 0.4792 - accuracy: 0.9171 - val_loss: 1.0640 - val_accuracy: 0.8185
# Epoch 61/100
# 313/313 [==============================] - 7s 23ms/step - loss: 0.4713 - accuracy: 0.9147 - val_loss: 1.0456 - val_accuracy: 0.8265
# Epoch 62/100
# 313/313 [==============================] - 7s 23ms/step - loss: 0.4600 - accuracy: 0.9205 - val_loss: 1.0251 - val_accuracy: 0.8225
# Epoch 63/100
# 313/313 [==============================] - 7s 23ms/step - loss: 0.4505 - accuracy: 0.9230 - val_loss: 1.0301 - val_accuracy: 0.8245
# Epoch 64/100
# 313/313 [==============================] - 7s 23ms/step - loss: 0.4528 - accuracy: 0.9233 - val_loss: 1.0777 - val_accuracy: 0.8170
# Epoch 65/100
# 313/313 [==============================] - 7s 22ms/step - loss: 0.4382 - accuracy: 0.9241 - val_loss: 1.0629 - val_accuracy: 0.8225
# Epoch 66/100
# 313/313 [==============================] - 7s 23ms/step - loss: 0.4370 - accuracy: 0.9223 - val_loss: 1.0784 - val_accuracy: 0.8200
# Epoch 67/100
# 313/313 [==============================] - 7s 23ms/step - loss: 0.4348 - accuracy: 0.9252 - val_loss: 1.0879 - val_accuracy: 0.8215
# Epoch 68/100
# 313/313 [==============================] - 7s 23ms/step - loss: 0.4383 - accuracy: 0.9182 - val_loss: 1.0590 - val_accuracy: 0.8280
# Epoch 69/100
# 313/313 [==============================] - 7s 23ms/step - loss: 0.4289 - accuracy: 0.9236 - val_loss: 1.1539 - val_accuracy: 0.8160
# Epoch 70/100
# 313/313 [==============================] - 7s 22ms/step - loss: 0.4188 - accuracy: 0.9253 - val_loss: 1.0983 - val_accuracy: 0.8225
# Epoch 71/100
# 313/313 [==============================] - 7s 23ms/step - loss: 0.4233 - accuracy: 0.9227 - val_loss: 1.0917 - val_accuracy: 0.8185
# Epoch 72/100
# 313/313 [==============================] - 7s 23ms/step - loss: 0.4103 - accuracy: 0.9261 - val_loss: 1.0553 - val_accuracy: 0.8300
# Epoch 73/100
# 313/313 [==============================] - 7s 23ms/step - loss: 0.4125 - accuracy: 0.9239 - val_loss: 1.0838 - val_accuracy: 0.8225
# Epoch 74/100
# 313/313 [==============================] - 7s 23ms/step - loss: 0.4060 - accuracy: 0.9226 - val_loss: 1.0703 - val_accuracy: 0.8230
# Epoch 75/100
# 313/313 [==============================] - 7s 23ms/step - loss: 0.3982 - accuracy: 0.9291 - val_loss: 1.0898 - val_accuracy: 0.8220
# Epoch 76/100
# 313/313 [==============================] - 7s 23ms/step - loss: 0.3957 - accuracy: 0.9280 - val_loss: 1.1141 - val_accuracy: 0.8200
# Epoch 77/100
# 313/313 [==============================] - 7s 23ms/step - loss: 0.4073 - accuracy: 0.9208 - val_loss: 1.0872 - val_accuracy: 0.8265
# Epoch 78/100
# 313/313 [==============================] - 7s 23ms/step - loss: 0.3927 - accuracy: 0.9286 - val_loss: 1.0891 - val_accuracy: 0.8215
# Epoch 79/100
# 313/313 [==============================] - 7s 24ms/step - loss: 0.3963 - accuracy: 0.9224 - val_loss: 1.1136 - val_accuracy: 0.8240
# Epoch 80/100
# 313/313 [==============================] - 7s 23ms/step - loss: 0.3907 - accuracy: 0.9257 - val_loss: 1.1226 - val_accuracy: 0.8285
# Epoch 81/100
# 313/313 [==============================] - 7s 23ms/step - loss: 0.3852 - accuracy: 0.9278 - val_loss: 1.0981 - val_accuracy: 0.8210
# Epoch 82/100
# 313/313 [==============================] - 7s 23ms/step - loss: 0.3813 - accuracy: 0.9256 - val_loss: 1.2311 - val_accuracy: 0.8160
# Epoch 83/100
# 313/313 [==============================] - 7s 23ms/step - loss: 0.3731 - accuracy: 0.9314 - val_loss: 1.1603 - val_accuracy: 0.8130
# Epoch 84/100
# 313/313 [==============================] - 7s 22ms/step - loss: 0.3841 - accuracy: 0.9222 - val_loss: 1.1296 - val_accuracy: 0.8190
# Epoch 85/100
# 313/313 [==============================] - 7s 23ms/step - loss: 0.3699 - accuracy: 0.9303 - val_loss: 1.1122 - val_accuracy: 0.8215
# Epoch 86/100
# 313/313 [==============================] - 7s 22ms/step - loss: 0.3824 - accuracy: 0.9252 - val_loss: 1.1580 - val_accuracy: 0.8145
# Epoch 87/100
# 313/313 [==============================] - 7s 23ms/step - loss: 0.3778 - accuracy: 0.9252 - val_loss: 1.1180 - val_accuracy: 0.8230
# Epoch 88/100
# 313/313 [==============================] - 7s 23ms/step - loss: 0.3733 - accuracy: 0.9222 - val_loss: 1.2469 - val_accuracy: 0.7995
# Epoch 89/100
# 313/313 [==============================] - 7s 23ms/step - loss: 0.3691 - accuracy: 0.9252 - val_loss: 1.1834 - val_accuracy: 0.8200
# Epoch 90/100
# 313/313 [==============================] - 7s 23ms/step - loss: 0.3745 - accuracy: 0.9256 - val_loss: 1.1048 - val_accuracy: 0.8225
# Epoch 91/100
# 313/313 [==============================] - 7s 22ms/step - loss: 0.3573 - accuracy: 0.9297 - val_loss: 1.1314 - val_accuracy: 0.8200
# Epoch 92/100
# 313/313 [==============================] - 7s 23ms/step - loss: 0.3627 - accuracy: 0.9263 - val_loss: 1.1393 - val_accuracy: 0.8190
# Epoch 93/100
# 313/313 [==============================] - 7s 23ms/step - loss: 0.3579 - accuracy: 0.9261 - val_loss: 1.1325 - val_accuracy: 0.8230
# Epoch 94/100
# 313/313 [==============================] - 7s 23ms/step - loss: 0.3610 - accuracy: 0.9276 - val_loss: 1.2082 - val_accuracy: 0.8160
# Epoch 95/100
# 313/313 [==============================] - 7s 22ms/step - loss: 0.3613 - accuracy: 0.9266 - val_loss: 1.2185 - val_accuracy: 0.8115
# Epoch 96/100
# 313/313 [==============================] - 7s 23ms/step - loss: 0.3608 - accuracy: 0.9266 - val_loss: 1.1710 - val_accuracy: 0.8195
#
# Epoch 00096: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
# Epoch 97/100
# 313/313 [==============================] - 7s 22ms/step - loss: 0.3477 - accuracy: 0.9300 - val_loss: 1.1649 - val_accuracy: 0.8185
# Epoch 98/100
# 313/313 [==============================] - 7s 23ms/step - loss: 0.3472 - accuracy: 0.9293 - val_loss: 1.1440 - val_accuracy: 0.8195
# Epoch 99/100
# 313/313 [==============================] - 7s 23ms/step - loss: 0.3397 - accuracy: 0.9346 - val_loss: 1.1457 - val_accuracy: 0.8180
# Epoch 100/100
# 313/313 [==============================] - 7s 23ms/step - loss: 0.3447 - accuracy: 0.9273 - val_loss: 1.1512 - val_accuracy: 0.8170

# %%
from explainability import LayerwiseRelevancePropagator

image_idx = 0

explanations = np.zeros((10, 16, 16, 16, 1))
predictions = model.predict(train_X[image_idx:image_idx + 1])
print(f'Predictions: {predictions[0]}')

for i in range(10):
    explainer = LayerwiseRelevancePropagator(model, layer=33, idx=i, epsilon=1e-3)
    explanations[i] = explainer(train_X[image_idx:image_idx + 1])
    print(f'Sum evidence for {i}: {np.sum(explanations[i])}')
# Out:
# Predictions: [2.24270957e-09 7.00051217e-08 2.81286368e-04 3.12355260e-04
#  1.17062456e-07 9.99366701e-01 3.01169748e-05 5.58828290e-08
#  1.06051168e-08 9.33957745e-06]
# Sum evidence for 0: -10.489566278178245
# Sum evidence for 1: -7.700538493460044
# Sum evidence for 2: -0.9731015040742932
# Sum evidence for 3: -0.8882672540348722
# Sum evidence for 4: -7.282903042854741
# Sum evidence for 5: 5.654211036162451
# Sum evidence for 6: -2.78395370094222
# Sum evidence for 7: -7.8824521489441395
# Sum evidence for 8: -9.232690917793661
# Sum evidence for 9: -3.7332287107710727

# %%
model.save_weights('/home/esten/tmp_weights.hdf5')

# %%
for i in range(len(explanations)):
    explanations[i] = explanations[i] / np.amax(np.abs(explanations[i]))
    explanations[i] -= explanations[i,0,0,0,0]
    
    fig, ax = plt.subplots(2, 16, figsize=(30, 5))
    fig.suptitle(f'{i} ({round(predictions[0,i], 2)})')
    
    for j in range(16):
        ax[0][j].imshow(train_X[image_idx,:,:,j])
        ax[1][j].imshow(explanations[i,:,:,j], cmap='seismic', clim=(-1, 1))
        ax[0][j].axis('off')
        ax[1][j].axis('off')
        
    plt.show()

# %%
fig, ax = plt.subplots(10, 10, figsize=(20, 20))

for i in range(10):
    for j in range(10):
        ax[i][j].axis('off')
        ax[i][j].imshow(explanations[i,:,:,5] - explanations[j,:,:,5], cmap='seismic', clim=(-1, 1))
        
plt.show()
