# %%
import h5py
import os
import matplotlib.pyplot as plt
import numpy as np

data_path = os.path.join(os.path.expanduser('~'), 'data', '3d-mnist', 
                         'full_dataset_vectors.h5')

assert os.path.isfile(data_path), \
    'Download the 3d-mnist data from https://www.kaggle.com/daavoo/3d-mnist'

with h5py.File(data_path, 'r') as f:
    train_X = np.reshape(f["X_train"][:], (-1, 16, 16, 16, 1))
    train_y = f["y_train"][:]    
    test_X = np.reshape(f["X_test"][:]  , (-1, 16, 16, 16, 1))
    test_y = f["y_test"][:]

train_X = train_X[:,::-1,:,:]
test_X = test_X[:,::-1,:,:]

def onehot(values: np.ndarray) -> np.ndarray:
    encoded = np.zeros((len(values), 10))

    for i in range(len(values)):
        encoded[i,values[i]] = 1

    return encoded

train_y = onehot(train_y)
test_y = onehot(test_y)

for i in range(5):
    fig, ax = plt.subplots(4, 4)
    fig.suptitle(str(np.argmax(train_y[i])))
    ax = ax.ravel()

    for j in range(16):
        ax[j].imshow(train_X[i,:,:,j])
        ax[j].axis('off')

    plt.show()

# %%
from tensorflow.keras import Model
from tensorflow.keras.layers import Activation, BatchNormalization, Conv3D, Dense, \
                                    Dropout, Flatten, \
                                    GlobalAveragePooling3D, Input, \
                                    MaxPooling3D
from tensorflow.keras.regularizers import l2

inputs = Input((16, 16, 16, 1), name='inputs')

x = inputs

kernel = (3, 3, 3)
dropout = 0.3
weight_decay = 1e-3
regularizer = l2(weight_decay)

x = Conv3D(32, kernel, padding='SAME', activation=None, 
           kernel_regularizer=regularizer, name='conv1')(x)
x = BatchNormalization(name='norm1')(x)
x = Activation('relu')(x)
x = Conv3D(32, kernel, padding='SAME', activation=None, 
           kernel_regularizer=regularizer, name='conv2')(x)
x = BatchNormalization(name='norm2')(x)
x = Activation('relu')(x)
x = MaxPooling3D((2, 2, 2), name='pool1')(x)
x = Conv3D(64, kernel, padding='SAME', activation=None, 
           kernel_regularizer=regularizer, name='conv3')(x)
x = BatchNormalization(name='norm3')(x)
x = Activation('relu')(x)
x = Conv3D(64, kernel, padding='SAME', activation=None, 
           kernel_regularizer=regularizer, name='conv4')(x)
x = BatchNormalization(name='norm4')(x)
x = Activation('relu')(x)
x = MaxPooling3D((2, 2, 2), name='pool2')(x)
x = Conv3D(128, kernel, padding='SAME', activation=None, 
           kernel_regularizer=regularizer, name='conv5')(x)
x = BatchNormalization(name='norm5')(x)
x = Activation('relu')(x)
x = Conv3D(128, kernel, padding='SAME', activation=None, 
           kernel_regularizer=regularizer, name='conv6')(x)
x = BatchNormalization(name='norm6')(x)
x = MaxPooling3D((2, 2, 2), name='pool3')(x)
x = Conv3D(256, kernel, padding='SAME', activation=None, 
           kernel_regularizer=regularizer, name='conv7')(x)
x = BatchNormalization(name='norm7')(x)
x = Activation('relu')(x)
x = Conv3D(256, kernel, padding='SAME', activation=None, 
           kernel_regularizer=regularizer, name='conv8')(x)
x = BatchNormalization(name='norm8')(x)
x = Activation('relu')(x)
x = GlobalAveragePooling3D(name='pool4')(x)
x = Dropout(dropout)(x)
x = Dense(10, kernel_regularizer=regularizer, activation=None, name='dense')(x)
x = BatchNormalization(name='norm9')(x)
x = Activation('relu')(x)
x = Dropout(dropout)(x)
x = Dense(10, activation='softmax', name='preds')(x)

model = Model(inputs, x)
model.summary()
# Out:
# 2022-03-09 22:09:58.460312: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# inputs (InputLayer)          [(None, 16, 16, 16, 1)]   0
# _________________________________________________________________
# conv1 (Conv3D)               (None, 16, 16, 16, 32)    896
# _________________________________________________________________
# norm1 (BatchNormalization)   (None, 16, 16, 16, 32)    128
# _________________________________________________________________
# activation (Activation)      (None, 16, 16, 16, 32)    0
# _________________________________________________________________
# conv2 (Conv3D)               (None, 16, 16, 16, 32)    27680
# _________________________________________________________________
# norm2 (BatchNormalization)   (None, 16, 16, 16, 32)    128
# _________________________________________________________________
# activation_1 (Activation)    (None, 16, 16, 16, 32)    0
# _________________________________________________________________
# pool1 (MaxPooling3D)         (None, 8, 8, 8, 32)       0
# _________________________________________________________________
# conv3 (Conv3D)               (None, 8, 8, 8, 64)       55360
# _________________________________________________________________
# norm3 (BatchNormalization)   (None, 8, 8, 8, 64)       256
# _________________________________________________________________
# activation_2 (Activation)    (None, 8, 8, 8, 64)       0
# _________________________________________________________________
# conv4 (Conv3D)               (None, 8, 8, 8, 64)       110656
# _________________________________________________________________
# norm4 (BatchNormalization)   (None, 8, 8, 8, 64)       256
# _________________________________________________________________
# activation_3 (Activation)    (None, 8, 8, 8, 64)       0
# _________________________________________________________________
# pool2 (MaxPooling3D)         (None, 4, 4, 4, 64)       0
# _________________________________________________________________
# conv5 (Conv3D)               (None, 4, 4, 4, 128)      221312
# _________________________________________________________________
# norm5 (BatchNormalization)   (None, 4, 4, 4, 128)      512
# _________________________________________________________________
# activation_4 (Activation)    (None, 4, 4, 4, 128)      0
# _________________________________________________________________
# conv6 (Conv3D)               (None, 4, 4, 4, 128)      442496
# _________________________________________________________________
# norm6 (BatchNormalization)   (None, 4, 4, 4, 128)      512
# _________________________________________________________________
# pool3 (MaxPooling3D)         (None, 2, 2, 2, 128)      0
# _________________________________________________________________
# conv7 (Conv3D)               (None, 2, 2, 2, 256)      884992
# _________________________________________________________________
# norm7 (BatchNormalization)   (None, 2, 2, 2, 256)      1024
# _________________________________________________________________
# activation_5 (Activation)    (None, 2, 2, 2, 256)      0
# _________________________________________________________________
# conv8 (Conv3D)               (None, 2, 2, 2, 256)      1769728
# _________________________________________________________________
# norm8 (BatchNormalization)   (None, 2, 2, 2, 256)      1024
# _________________________________________________________________
# activation_6 (Activation)    (None, 2, 2, 2, 256)      0
# _________________________________________________________________
# pool4 (GlobalAveragePooling3 (None, 256)               0
# _________________________________________________________________
# dropout (Dropout)            (None, 256)               0
# _________________________________________________________________
# dense (Dense)                (None, 10)                2570
# _________________________________________________________________
# norm9 (BatchNormalization)   (None, 10)                40
# _________________________________________________________________
# activation_7 (Activation)    (None, 10)                0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 10)                0
# _________________________________________________________________
# preds (Dense)                (None, 10)                110
# =================================================================
# Total params: 3,519,680
# Trainable params: 3,517,740
# Non-trainable params: 1,940
# _________________________________________________________________
# 2022-03-09 22:09:58.466824: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-03-09 22:09:58.467132: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-03-09 22:09:58.468134: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-03-09 22:09:58.468556: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-03-09 22:09:58.468866: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-03-09 22:09:58.469033: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-03-09 22:09:58.902289: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-03-09 22:09:58.902458: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-03-09 22:09:58.902590: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-03-09 22:09:58.902708: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1510] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 11068 MB memory:  -> device: 0, name: NVIDIA TITAN X (Pascal), pci bus id: 0000:01:00.0, compute capability: 6.1

# %%
from tensorflow.keras.callbacks import ReduceLROnPlateau
from tensorflow.keras.optimizers import Adam

model.compile(loss='categorical_crossentropy', optimizer=Adam(1e-3),
              metrics=['accuracy'])

callbacks = [
    ReduceLROnPlateau(
        monitor="loss",
        factor=0.1,
        patience=5,
        verbose=1
    )
]

model.fit(train_X, train_y, 
          validation_data=(test_X, test_y), 
          epochs=100, 
          batch_size=32, 
          shuffle=True,
          callbacks=callbacks)
# Out:
# 2022-03-09 22:09:59.598512: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:185] None of the MLIR Optimization Passes are enabled (registered 2)
# Epoch 1/100
# 2022-03-09 22:10:01.027696: I tensorflow/stream_executor/cuda/cuda_dnn.cc:369] Loaded cuDNN version 8100
# 2022-03-09 22:10:01.216099: W tensorflow/stream_executor/gpu/asm_compiler.cc:113] *** WARNING *** You are using ptxas 9.1.108, which is older than 9.2.88. ptxas 9.x before 9.2.88 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You do not need to update to CUDA 9.2.88; cherry-picking the ptxas binary is sufficient.
# 313/313 [==============================] - 9s 22ms/step - loss: 2.5379 - accuracy: 0.3055 - val_loss: 5.1629 - val_accuracy: 0.1270
# Epoch 2/100
# 313/313 [==============================] - 7s 21ms/step - loss: 1.9084 - accuracy: 0.4539 - val_loss: 1.9115 - val_accuracy: 0.4410
# Epoch 3/100
# 313/313 [==============================] - 7s 22ms/step - loss: 1.7689 - accuracy: 0.4768 - val_loss: 1.5757 - val_accuracy: 0.5555
# Epoch 4/100
# 313/313 [==============================] - 7s 21ms/step - loss: 1.7049 - accuracy: 0.5078 - val_loss: 1.8105 - val_accuracy: 0.4945
# Epoch 5/100
# 313/313 [==============================] - 7s 21ms/step - loss: 1.6319 - accuracy: 0.5290 - val_loss: 1.6740 - val_accuracy: 0.5295
# Epoch 6/100
# 313/313 [==============================] - 7s 21ms/step - loss: 1.5961 - accuracy: 0.5434 - val_loss: 1.5774 - val_accuracy: 0.5715
# Epoch 7/100
# 313/313 [==============================] - 7s 21ms/step - loss: 1.5935 - accuracy: 0.5510 - val_loss: 1.6003 - val_accuracy: 0.5670
# Epoch 8/100
# 313/313 [==============================] - 7s 21ms/step - loss: 1.5584 - accuracy: 0.5611 - val_loss: 1.5090 - val_accuracy: 0.6005
# Epoch 9/100
# 313/313 [==============================] - 7s 21ms/step - loss: 1.5067 - accuracy: 0.5801 - val_loss: 1.4082 - val_accuracy: 0.6325
# Epoch 10/100
# 313/313 [==============================] - 7s 21ms/step - loss: 1.4983 - accuracy: 0.5891 - val_loss: 1.3276 - val_accuracy: 0.6690
# Epoch 11/100
# 313/313 [==============================] - 7s 21ms/step - loss: 1.4389 - accuracy: 0.6117 - val_loss: 1.3754 - val_accuracy: 0.6600
# Epoch 12/100
# 313/313 [==============================] - 7s 22ms/step - loss: 1.4175 - accuracy: 0.6173 - val_loss: 1.4028 - val_accuracy: 0.6505
# Epoch 13/100
# 313/313 [==============================] - 7s 22ms/step - loss: 1.3981 - accuracy: 0.6267 - val_loss: 1.2417 - val_accuracy: 0.6830
# Epoch 14/100
# 313/313 [==============================] - 7s 22ms/step - loss: 1.3533 - accuracy: 0.6403 - val_loss: 1.1917 - val_accuracy: 0.6950
# Epoch 15/100
# 313/313 [==============================] - 7s 22ms/step - loss: 1.3120 - accuracy: 0.6556 - val_loss: 1.1798 - val_accuracy: 0.7095
# Epoch 16/100
# 313/313 [==============================] - 7s 22ms/step - loss: 1.2928 - accuracy: 0.6656 - val_loss: 1.6985 - val_accuracy: 0.5565
# Epoch 17/100
# 313/313 [==============================] - 7s 21ms/step - loss: 1.2513 - accuracy: 0.6744 - val_loss: 1.3497 - val_accuracy: 0.6545
# Epoch 18/100
# 313/313 [==============================] - 7s 22ms/step - loss: 1.2467 - accuracy: 0.6730 - val_loss: 1.0792 - val_accuracy: 0.7420
# Epoch 19/100
# 313/313 [==============================] - 7s 23ms/step - loss: 1.2157 - accuracy: 0.6904 - val_loss: 1.0687 - val_accuracy: 0.7515
# Epoch 20/100
# 313/313 [==============================] - 7s 22ms/step - loss: 1.1850 - accuracy: 0.6962 - val_loss: 1.1143 - val_accuracy: 0.7350
# Epoch 21/100
# 313/313 [==============================] - 7s 22ms/step - loss: 1.1674 - accuracy: 0.7033 - val_loss: 1.0511 - val_accuracy: 0.7595
# Epoch 22/100
# 313/313 [==============================] - 7s 23ms/step - loss: 1.1246 - accuracy: 0.7155 - val_loss: 1.0364 - val_accuracy: 0.7600
# Epoch 23/100
# 313/313 [==============================] - 7s 23ms/step - loss: 1.1404 - accuracy: 0.7178 - val_loss: 1.4035 - val_accuracy: 0.6625
# Epoch 24/100
# 313/313 [==============================] - 7s 22ms/step - loss: 1.1012 - accuracy: 0.7231 - val_loss: 1.0652 - val_accuracy: 0.7510
# Epoch 25/100
# 313/313 [==============================] - 7s 22ms/step - loss: 1.0702 - accuracy: 0.7414 - val_loss: 1.2570 - val_accuracy: 0.7175
# Epoch 26/100
# 313/313 [==============================] - 7s 22ms/step - loss: 1.1024 - accuracy: 0.7265 - val_loss: 1.2386 - val_accuracy: 0.7145
# Epoch 27/100
# 313/313 [==============================] - 7s 22ms/step - loss: 1.0527 - accuracy: 0.7456 - val_loss: 1.1560 - val_accuracy: 0.7410
# Epoch 28/100
# 313/313 [==============================] - 7s 23ms/step - loss: 1.0679 - accuracy: 0.7418 - val_loss: 3.0286 - val_accuracy: 0.4890
# Epoch 29/100
# 313/313 [==============================] - 7s 22ms/step - loss: 1.0289 - accuracy: 0.7528 - val_loss: 1.1611 - val_accuracy: 0.7280
# Epoch 30/100
# 313/313 [==============================] - 7s 22ms/step - loss: 1.0608 - accuracy: 0.7511 - val_loss: 1.1460 - val_accuracy: 0.7600
# Epoch 31/100
# 313/313 [==============================] - 7s 23ms/step - loss: 1.
100
# 313/313 [==============================] - 7s 23ms/step - loss: 0.5484 - accuracy: 0.9153 - val_loss: 1.0511 - val_accuracy: 0.8265
# Epoch 62/100
# 313/313 [==============================] - 7s 23ms/step - loss: 0.5496 - accuracy: 0.9127 - val_loss: 1.0439 - val_accuracy: 0.8295
# Epoch 63/100
# 313/313 [==============================] - 7s 23ms/step - loss: 0.5238 - accuracy: 0.9178 - val_loss: 1.0274 - val_accuracy: 0.8350
# Epoch 64/100
# 313/313 [==============================] - 7s 23ms/step - loss: 0.5131 - accuracy: 0.9198 - val_loss: 1.0702 - val_accuracy: 0.8245
# Epoch 65/100
# 313/313 [==============================] - 7s 23ms/step - loss: 0.5063 - accuracy: 0.9185 - val_loss: 1.0520 - val_accuracy: 0.8275
# Epoch 66/100
# 313/313 [==============================] - 7s 23ms/step - loss: 0.4957 - accuracy: 0.9204 - val_loss: 1.0246 - val_accuracy: 0.8320
# Epoch 67/100
# 313/313 [==============================] - 7s 24ms/step - loss: 0.4932 - accuracy: 0.9209 - val_loss: 1.0314 - val_accuracy: 0.8345
# Epoch 68/100
# 313/313 [==============================] - 7s 23ms/step - loss: 0.4879 - accuracy: 0.9177 - val_loss: 1.0747 - val_accuracy: 0.8300
# Epoch 69/100
# 313/313 [==============================] - 7s 23ms/step - loss: 0.4683 - accuracy: 0.9246 - val_loss: 1.0935 - val_accuracy: 0.8225
# Epoch 70/100
# 313/313 [==============================] - 7s 23ms/step - loss: 0.4597 - accuracy: 0.9278 - val_loss: 1.0810 - val_accuracy: 0.8235
# Epoch 71/100
# 313/313 [==============================] - 7s 23ms/step - loss: 0.4508 - accuracy: 0.9290 - val_loss: 1.0648 - val_accuracy: 0.8325
# Epoch 72/100
# 313/313 [==============================] - 7s 22ms/step - loss: 0.4547 - accuracy: 0.9267 - val_loss: 1.0775 - val_accuracy: 0.8245
# Epoch 73/100
# 313/313 [==============================] - 7s 23ms/step - loss: 0.4447 - accuracy: 0.9259 - val_loss: 1.0991 - val_accuracy: 0.8290
# Epoch 74/100
# 313/313 [==============================] - 7s 23ms/step - loss: 0.4426 - accuracy: 0.9278 - val_loss: 1.0609 - val_accuracy: 0.8280
# Epoch 75/100
# 313/313 [==============================] - 7s 23ms/step - loss: 0.4343 - accuracy: 0.9258 - val_loss: 1.0582 - val_accuracy: 0.8305
# Epoch 76/100
# 313/313 [==============================] - 7s 23ms/step - loss: 0.4230 - accuracy: 0.9298 - val_loss: 1.1053 - val_accuracy: 0.8200
# Epoch 77/100
# 313/313 [==============================] - 7s 22ms/step - loss: 0.4226 - accuracy: 0.9304 - val_loss: 1.0733 - val_accuracy: 0.8270
# Epoch 78/100
# 313/313 [==============================] - 7s 23ms/step - loss: 0.4179 - accuracy: 0.9267 - val_loss: 1.0747 - val_accuracy: 0.8220
# Epoch 79/100
# 313/313 [==============================] - 7s 23ms/step - loss: 0.4149 - accuracy: 0.9263 - val_loss: 1.0450 - val_accuracy: 0.8285
# Epoch 80/100
# 313/313 [==============================] - 7s 23ms/step - loss: 0.4083 - accuracy: 0.9307 - val_loss: 1.0811 - val_accuracy: 0.8335
# Epoch 81/100
# 313/313 [==============================] - 7s 22ms/step - loss: 0.4102 - accuracy: 0.9246 - val_loss: 1.0750 - val_accuracy: 0.8265
# Epoch 82/100
# 313/313 [==============================] - 7s 23ms/step - loss: 0.4067 - accuracy: 0.9278 - val_loss: 1.0643 - val_accuracy: 0.8285
# Epoch 83/100
# 313/313 [==============================] - 7s 23ms/step - loss: 0.4117 - accuracy: 0.9224 - val_loss: 1.0781 - val_accuracy: 0.8280
# Epoch 84/100
# 313/313 [==============================] - 7s 23ms/step - loss: 0.3938 - accuracy: 0.9322 - val_loss: 1.0982 - val_accuracy: 0.8240
# Epoch 85/100
# 313/313 [==============================] - 7s 22ms/step - loss: 0.3982 - accuracy: 0.9233 - val_loss: 1.1158 - val_accuracy: 0.8245
# Epoch 86/100
# 313/313 [==============================] - 7s 22ms/step - loss: 0.3875 - accuracy: 0.9287 - val_loss: 1.1099 - val_accuracy: 0.8230
# Epoch 87/100
# 313/313 [==============================] - 7s 23ms/step - loss: 0.3874 - accuracy: 0.9302 - val_loss: 1.1357 - val_accuracy: 0.8215
# Epoch 88/100
# 313/313 [==============================] - 7s 22ms/step - loss: 0.3782 - accuracy: 0.9326 - val_loss: 1.0953 - val_accuracy: 0.8245
# Epoch 89/100
# 313/313 [==============================] - 7s 23ms/step - loss: 0.3746 - accuracy: 0.9299 - val_loss: 1.0844 - val_accuracy: 0.8305
# Epoch 90/100
# 313/313 [==============================] - 7s 23ms/step - loss: 0.3726 - accuracy: 0.9302 - val_loss: 1.1600 - val_accuracy: 0.8135
# Epoch 91/100
# 313/313 [==============================] - 7s 23ms/step - loss: 0.3719 - accuracy: 0.9304 - val_loss: 1.1285 - val_accuracy: 0.8310
# Epoch 92/100
# 313/313 [==============================] - 7s 23ms/step - loss: 0.3643 - accuracy: 0.9331 - val_loss: 1.1190 - val_accuracy: 0.8340
# Epoch 93/100
# 313/313 [==============================] - 7s 23ms/step - loss: 0.3695 - accuracy: 0.9264 - val_loss: 1.1052 - val_accuracy: 0.8295
# Epoch 94/100
# 313/313 [==============================] - 7s 23ms/step - loss: 0.3556 - accuracy: 0.9325 - val_loss: 1.0915 - val_accuracy: 0.8315
# Epoch 95/100
# 313/313 [==============================] - 7s 22ms/step - loss: 0.3526 - accuracy: 0.9343 - val_loss: 1.1412 - val_accuracy: 0.8240
# Epoch 96/100
# 313/313 [==============================] - 7s 23ms/step - loss: 0.3630 - accuracy: 0.9282 - val_loss: 1.1302 - val_accuracy: 0.8185
# Epoch 97/100
# 313/313 [==============================] - 7s 23ms/step - loss: 0.3572 - accuracy: 0.9293 - val_loss: 1.1468 - val_accuracy: 0.8255
# Epoch 98/100
# 313/313 [==============================] - 7s 23ms/step - loss: 0.3610 - accuracy: 0.9270 - val_loss: 1.1848 - val_accuracy: 0.8255
# Epoch 99/100
# 313/313 [==============================] - 7s 23ms/step - loss: 0.3540 - accuracy: 0.9276 - val_loss: 1.1004 - val_accuracy: 0.8235
# Epoch 100/100
# 313/313 [==============================] - 7s 23ms/step - loss: 0.3491 - accuracy: 0.9308 - val_loss: 1.1689 - val_accuracy: 0.8170

# %%
from explainability import LayerwiseRelevancePropagator

image_idx = 0

explanations = np.zeros((10, 16, 16, 16, 1))
predictions = model.predict(train_X[image_idx:image_idx + 1])
print(f'Predictions: {predictions[0]}')

for i in range(10):
    explainer = LayerwiseRelevancePropagator(model, layer=33, idx=i, alpha=2, beta=1)
    explanations[i] = explainer(train_X[image_idx:image_idx + 1])
    print(f'Sum evidence for {i}: {np.sum(explanations[i])}')
# Out:
# Predictions: [1.8740088e-11 6.4668507e-11 2.3255700e-03 3.1848613e-05 3.6103613e-06
#  9.9744487e-01 2.0814472e-05 1.0505788e-06 8.5907567e-07 1.7143028e-04]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_6655/331748823.py in <module>
#       8
#       9 for i in range(10):
# ---> 10     explainer = LayerwiseRelevancePropagator(model, layer=33, idx=i)
#      11     explanations[i] = explainer(train_X[image_idx:image_idx + 1])
#      12     print(f'Sum evidence for {i}: {np.sum(explanations[i])}')
#
# ~/repos/keras-explainability/explainability/model/lrp.py in __init__(self, model, epsilon, gamma, alpha, beta, layer, idx)
#      33                 beta=beta,
#      34                 name=f'{i}'
# ---> 35             )([activations[i-1], prev])
#      36
#      37         super().__init__(model.input, prev)
#
# ~/miniconda3/envs/ml/lib/python3.7/site-packages/keras/engine/base_layer.py in __call__(self, *args, **kwargs)
#     975     if _in_functional_construction_mode(self, inputs, args, kwargs, input_list):
#     976       return self._functional_construction_call(inputs, args, kwargs,
# --> 977                                                 input_list)
#     978
#     979     # Maintains info about the `Layer.call` stack.
#
# ~/miniconda3/envs/ml/lib/python3.7/site-packages/keras/engine/base_layer.py in _functional_construction_call(self, inputs, args, kwargs, input_list)
#    1113       # Check input assumptions set after layer building, e.g. input shape.
#    1114       outputs = self._keras_tensor_symbolic_call(
# -> 1115           inputs, input_masks, args, kwargs)
#    1116
#    1117       if outputs is None:
#
# ~/miniconda3/envs/ml/lib/python3.7/site-packages/keras/engine/base_layer.py in _keras_tensor_symbolic_call(self, inputs, input_masks, args, kwargs)
#     846       return tf.nest.map_structure(keras_tensor.KerasTensor, output_signature)
#     847     else:
# --> 848       return self._infer_output_signature(inputs, args, kwargs, input_masks)
#     849
#     850   def _infer_output_signature(self, inputs, args, kwargs, input_masks):
#
# ~/miniconda3/envs/ml/lib/python3.7/site-packages/keras/engine/base_layer.py in _infer_output_signature(self, inputs, args, kwargs, input_masks)
#     886           self._maybe_build(inputs)
#     887           inputs = self._maybe_cast_inputs(inputs)
# --> 888           outputs = call_fn(inputs, *args, **kwargs)
#     889
#     890         self._handle_activity_regularization(inputs, outputs)
#
# ~/miniconda3/envs/ml/lib/python3.7/site-packages/tensorflow/python/autograph/impl/api.py in wrapper(*args, **kwargs)
#     693       except Exception as e:  # pylint:disable=broad-except
#     694         if hasattr(e, 'ag_error_metadata'):
# --> 695           raise e.ag_error_metadata.to_exception(e)
#     696         else:
#     697           raise
#
# ValueError: in user code:
#
#     /home/esten/repos/keras-explainability/explainability/layers/layer.py:54 call  *
#         z = self.forward(a, w)
#     /home/esten/repos/keras-explainability/explainability/layers/conv.py:56 forward  *
#         return tf.nn.conv3d(a, w, strides=self.layer.strides,
#     /home/esten/miniconda3/envs/ml/lib/python3.7/site-packages/tensorflow/python/util/dispatch.py:206 wrapper  **
#         return target(*args, **kwargs)
#     /home/esten/miniconda3/envs/ml/lib/python3.7/site-packages/tensorflow/python/ops/nn_ops.py:3163 conv3d_v2
#         dilations, name)
#     /home/esten/miniconda3/envs/ml/lib/python3.7/site-packages/tensorflow/python/ops/nn_ops.py:3136 _conv3d_expanded_batch
#         name=name)
#     /home/esten/miniconda3/envs/ml/lib/python3.7/site-packages/tensorflow/python/ops/gen_nn_ops.py:1429 conv3d
#         dilations=dilations, name=name)
#     /home/esten/miniconda3/envs/ml/lib/python3.7/site-packages/tensorflow/python/framework/op_def_library.py:701 _apply_op_helper
#         _SatisfiesLengthConstraint(len(value), attr_def, key, op_type_name)
#     /home/esten/miniconda3/envs/ml/lib/python3.7/site-packages/tensorflow/python/framework/op_def_library.py:70 _SatisfiesLengthConstraint
#         (param_name, op_type_name, length, attr_def.minimum))
#
#     ValueError: Attr 'strides' of 'Conv3D' Op passed list of length 3 less than minimum 5.

# %%
model.save_weights('/home/esten/tmp_weights.hdf5')

# %%
model.save('~/tmp_model')

# %%
for i in range(len(explanations)):
    explanations[i] = (explanations[i] - np.amin(explanations[i])) / np.amax(explanations[i])
    explanations[i] -= explanations[i,0,0,0,0]
    
    fig, ax = plt.subplots(2, 16, figsize=(30, 5))
    fig.suptitle(f'{i} ({round(preds[0,i], 2)})')
    
    for j in range(16):
        ax[0][j].imshow(train_X[image_idx,:,:,j])
        ax[1][j].imshow(explanations[i,:,:,j], cmap='seismic', clim=(-1, 1))
        ax[0][j].axis('off')
        ax[1][j].axis('off')
        
    plt.show()

# %%
fig, ax = plt.subplots(10, 10, figsize=(20, 20))

for i in range(10):
    for j in range(10):
        ax[i][j].axis('off')
        ax[i][j].imshow(explanations[i,:,:,5] - explanations[j,:,:,5], cmap='seismic')
        
plt.show()

# %%
layers = [
    (33, 'prediction'),
    (35, 'mask'),
    (36, 'dense')
]

#for i in range(len(explainer.layers)):
#    print(f'{i}: {explainer.layers[i]}')

for layer, description in layers:
    layerwise_explanations = []
    for i in range(1):
        explainer = LayerwiseRelevancePropagator(model, layer=33, idx=i, alpha=1, beta=0)
        layerwise_explanations.append(explainer(train_X[image_idx:]))
        
    print(layerwise_explanations[0].shape)
# Out:
# 2022-03-09 16:59:18.214080: W tensorflow/core/framework/cpu_allocator_impl.cc:80] Allocation of 327680000 exceeds 10% of free system memory.
# 2022-03-09 16:59:18.444145: W tensorflow/core/kernels/gpu_utils.cc:49] Failed to allocate memory for convolution redzone checking; skipping this check. This is benign and only means that we won't check cudnn for out-of-bounds reads and writes. This message will only be printed once.
# 2022-03-09 16:59:28.539426: W tensorflow/core/common_runtime/bfc_allocator.cc:457] Allocator (GPU_0_bfc) ran out of memory trying to allocate 4.88GiB (rounded to 5242880000)requested by op Relu
# If the cause is memory fragmentation maybe the environment variable 'TF_GPU_ALLOCATOR=cuda_malloc_async' will improve the situation.
# Current allocation summary follows.
# Current allocation summary follows.
# 2022-03-09 16:59:28.539503: I tensorflow/core/common_runtime/bfc_allocator.cc:1004] BFCAllocator dump for GPU_0_bfc
# 2022-03-09 16:59:28.539545: I tensorflow/core/common_runtime/bfc_allocator.cc:1011] Bin (256): 	Total Chunks: 180, Chunks in use: 174. 45.0KiB allocated for chunks. 43.5KiB in use in bin. 9.6KiB client-requested in use in bin.
# 2022-03-09 16:59:28.539574: I tensorflow/core/common_runtime/bfc_allocator.cc:1011] Bin (512): 	Total Chunks: 25, Chunks in use: 25. 12.5KiB allocated for chunks. 12.5KiB in use in bin. 12.2KiB client-requested in use in bin.
# 2022-03-09 16:59:28.539598: I tensorflow/core/common_runtime/bfc_allocator.cc:1011] Bin (1024): 	Total Chunks: 25, Chunks in use: 23. 26.5KiB allocated for chunks. 24.0KiB in use in bin. 23.0KiB client-requested in use in bin.
# 2022-03-09 16:59:28.539621: I tensorflow/core/common_runtime/bfc_allocator.cc:1011] Bin (2048): 	Total Chunks: 4, Chunks in use: 4. 14.0KiB allocated for chunks. 14.0KiB in use in bin. 13.5KiB client-requested in use in bin.
# 2022-03-09 16:59:28.539644: I tensorflow/core/common_runtime/bfc_allocator.cc:1011] Bin (4096): 	Total Chunks: 1, Chunks in use: 0. 4.0KiB allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2022-03-09 16:59:28.539667: I tensorflow/core/common_runtime/bfc_allocator.cc:1011] Bin (8192): 	Total Chunks: 4, Chunks in use: 4. 40.0KiB allocated for chunks. 40.0KiB in use in bin. 40.0KiB client-requested in use in bin.
# 2022-03-09 16:59:28.539688: I tensorflow/core/common_runtime/bfc_allocator.cc:1011] Bin (16384): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2022-03-09 16:59:28.539708: I tensorflow/core/common_runtime/bfc_allocator.cc:1011] Bin (32768): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2022-03-09 16:59:28.539733: I tensorflow/core/common_runtime/bfc_allocator.cc:1011] Bin (65536): 	Total Chunks: 3, Chunks in use: 3. 324.0KiB allocated for chunks. 324.0KiB in use in bin. 324.0KiB client-requested in use in bin.
# 2022-03-09 16:59:28.539756: I tensorflow/core/common_runtime/bfc_allocator.cc:1011] Bin (131072): 	Total Chunks: 6, Chunks in use: 5. 1.18MiB allocated for chunks. 1.01MiB in use in bin. 972.0KiB client-requested in use in bin.
# 2022-03-09 16:59:28.539778: I tensorflow/core/common_runtime/bfc_allocator.cc:1011] Bin (262144): 	Total Chunks: 6, Chunks in use: 4. 2.42MiB allocated for chunks. 1.73MiB in use in bin. 1.69MiB client-requested in use in bin.
# 2022-03-09 16:59:28.539800: I tensorflow/core/common_runtime/bfc_allocator.cc:1011] Bin (524288): 	Total Chunks: 4, Chunks in use: 4. 3.46MiB allocated for chunks. 3.46MiB in use in bin. 3.38MiB client-requested in use in bin.
# 2022-03-09 16:59:28.539821: I tensorflow/core/common_runtime/bfc_allocator.cc:1011] Bin (1048576): 	Total Chunks: 4, Chunks in use: 4. 6.75MiB allocated for chunks. 6.75MiB in use in bin. 6.75MiB client-requested in use in bin.
# 2022-03-09 16:59:28.539846: I tensorflow/core/common_runtime/bfc_allocator.cc:1011] Bin (2097152): 	Total Chunks: 3, Chunks in use: 3. 10.12MiB allocated for chunks. 10.12MiB in use in bin. 10.12MiB client-requested in use in bin.
# 2022-03-09 16:59:28.539871: I tensorflow/core/common_runtime/bfc_allocator.cc:1011] Bin (4194304): 	Total Chunks: 5, Chunks in use: 5. 32.06MiB allocated for chunks. 32.06MiB in use in bin. 30.38MiB client-requested in use in bin.
# 2022-03-09 16:59:28.539891: I tensorflow/core/common_runtime/bfc_allocator.cc:1011] Bin (8388608): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2022-03-09 16:59:28.539911: I tensorflow/core/common_runtime/bfc_allocator.cc:1011] Bin (16777216): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2022-03-09 16:59:28.539931: I tensorflow/core/common_runtime/bfc_allocator.cc:1011] Bin (33554432): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2022-03-09 16:59:28.539955: I tensorflow/core/common_runtime/bfc_allocator.cc:1011] Bin (67108864): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2022-03-09 16:59:28.539981: I tensorflow/core/common_runtime/bfc_allocator.cc:1011] Bin (134217728): 	Total Chunks: 1, Chunks in use: 1. 156.25MiB allocated for chunks. 156.25MiB in use in bin. 156.25MiB client-requested in use in bin.
# 2022-03-09 16:59:28.540005: I tensorflow/core/common_runtime/bfc_allocator.cc:1011] Bin (268435456): 	Total Chunks: 4, Chunks in use: 3. 10.60GiB allocated for chunks. 10.07GiB in use in bin. 10.07GiB client-requested in use in bin.
# 2022-03-09 16:59:28.540027: I tensorflow/core/common_runtime/bfc_allocator.cc:1027] Bin for 4.88GiB was 256.00MiB, Chunk State:
# 2022-03-09 16:59:28.540059: I tensorflow/core/common_runtime/bfc_allocator.cc:1033]   Size: 543.54MiB | Requested Size: 16.0KiB | in_use: 0 | bin_num: 20, prev:   Size: 4.88GiB | Requested Size: 4.88GiB | in_use: 1 | bin_num: -1
# 2022-03-09 16:59:28.540077: I tensorflow/core/common_runtime/bfc_allocator.cc:1040] Next region of size 11606425600
# 2022-03-09 16:59:28.540098: I tensorflow/core/common_runtime/bfc_allocator.cc:1060] InUse at 7f14ac000000 of size 1280 next 1
# 2022-03-09 16:59:28.540116: I tensorflow/core/common_runtime/bfc_allocator.cc:1060] InUse at 7f14ac000500 of size 256 next 2
# 2022-03-09 16:59:28.540133: I tensorflow/core/common_runtime/bfc_allocator.cc:1060] InUse at 7f14ac000600 of size 256 next 3
# 2022-03-09 16:59:28.540149: I tensorflow/core/common_runtime/bfc_allocator.cc:1060] InUse at 7f14
I tensorflow/core/common_runtime/bfc_allocator.cc:1068] 3 Chunks of size 442368 totalling 1.27MiB
# 2022-03-09 16:59:28.544603: I tensorflow/core/common_runtime/bfc_allocator.cc:1068] 1 Chunks of size 484608 totalling 473.2KiB
# 2022-03-09 16:59:28.544607: I tensorflow/core/common_runtime/bfc_allocator.cc:1068] 3 Chunks of size 884736 totalling 2.53MiB
# 2022-03-09 16:59:28.544612: I tensorflow/core/common_runtime/bfc_allocator.cc:1068] 1 Chunks of size 975872 totalling 953.0KiB
# 2022-03-09 16:59:28.544616: I tensorflow/core/common_runtime/bfc_allocator.cc:1068] 4 Chunks of size 1769472 totalling 6.75MiB
# 2022-03-09 16:59:28.544621: I tensorflow/core/common_runtime/bfc_allocator.cc:1068] 3 Chunks of size 3538944 totalling 10.12MiB
# 2022-03-09 16:59:28.544625: I tensorflow/core/common_runtime/bfc_allocator.cc:1068] 1 Chunks of size 5305344 totalling 5.06MiB
# 2022-03-09 16:59:28.544630: I tensorflow/core/common_runtime/bfc_allocator.cc:1068] 4 Chunks of size 7077888 totalling 27.00MiB
# 2022-03-09 16:59:28.544634: I tensorflow/core/common_runtime/bfc_allocator.cc:1068] 1 Chunks of size 163840000 totalling 156.25MiB
# 2022-03-09 16:59:28.544639: I tensorflow/core/common_runtime/bfc_allocator.cc:1068] 1 Chunks of size 327680000 totalling 312.50MiB
# 2022-03-09 16:59:28.544643: I tensorflow/core/common_runtime/bfc_allocator.cc:1068] 2 Chunks of size 5242880000 totalling 9.77GiB
# 2022-03-09 16:59:28.544648: I tensorflow/core/common_runtime/bfc_allocator.cc:1072] Sum Total of in-use chunks: 10.28GiB
# 2022-03-09 16:59:28.544653: I tensorflow/core/common_runtime/bfc_allocator.cc:1074] total_region_allocated_bytes_: 11606425600 memory_limit_: 11606425600 available bytes: 0 curr_region_allocation_bytes_: 23212851200
# 2022-03-09 16:59:28.544661: I tensorflow/core/common_runtime/bfc_allocator.cc:1080] Stats:
# Limit:                     11606425600
# InUse:                     11035559680
# MaxInUse:                  11035563776
# NumAllocs:                    10414205
# MaxAllocSize:               5242880000
# Reserved:                            0
# PeakReserved:                        0
# LargestFreeBlock:                    0
#
# 2022-03-09 16:59:28.544677: W tensorflow/core/common_runtime/bfc_allocator.cc:468] ************************************************************************************************____
# 2022-03-09 16:59:28.544706: W tensorflow/core/framework/op_kernel.cc:1692] OP_REQUIRES failed at numeric_op.h:61 : Resource exhausted: OOM when allocating tensor with shape[10000,16,16,16,32] and type float on /job:localhost/replica:0/task:0/device:GPU:0 by allocator GPU_0_bfc
# ---------------------------------------------------------------------------
# ResourceExhaustedError                    Traceback (most recent call last)
# /tmp/ipykernel_28629/2515086044.py in <module>
#      12     for i in range(1):
#      13         explainer = LayerwiseRelevancePropagator(model, layer=33, idx=i, alpha=1, beta=0)
# ---> 14         layerwise_explanations.append(explainer(train_X[image_idx:]))
#      15
#      16     print(layerwise_explanations[0].shape)
#
# ~/miniconda3/envs/ml/lib/python3.7/site-packages/keras/engine/base_layer.py in __call__(self, *args, **kwargs)
#    1035         with autocast_variable.enable_auto_cast_variables(
#    1036             self._compute_dtype_object):
# -> 1037           outputs = call_fn(inputs, *args, **kwargs)
#    1038
#    1039         if self._activity_regularizer:
#
# ~/miniconda3/envs/ml/lib/python3.7/site-packages/keras/engine/functional.py in call(self, inputs, training, mask)
#     413     """
#     414     return self._run_internal_graph(
# --> 415         inputs, training=training, mask=mask)
#     416
#     417   def compute_output_shape(self, input_shape):
#
# ~/miniconda3/envs/ml/lib/python3.7/site-packages/keras/engine/functional.py in _run_internal_graph(self, inputs, training, mask)
#     548
#     549         args, kwargs = node.map_arguments(tensor_dict)
# --> 550         outputs = node.layer(*args, **kwargs)
#     551
#     552         # Update tensor_dict.
#
# ~/miniconda3/envs/ml/lib/python3.7/site-packages/keras/engine/base_layer.py in __call__(self, *args, **kwargs)
#    1035         with autocast_variable.enable_auto_cast_variables(
#    1036             self._compute_dtype_object):
# -> 1037           outputs = call_fn(inputs, *args, **kwargs)
#    1038
#    1039         if self._activity_regularizer:
#
# ~/miniconda3/envs/ml/lib/python3.7/site-packages/keras/layers/core.py in call(self, inputs)
#     420
#     421   def call(self, inputs):
# --> 422     return self.activation(inputs)
#     423
#     424   def compute_output_shape(self, input_shape):
#
# ~/miniconda3/envs/ml/lib/python3.7/site-packages/tensorflow/python/util/dispatch.py in wrapper(*args, **kwargs)
#     204     """Call target, and fall back on dispatchers if there is a TypeError."""
#     205     try:
# --> 206       return target(*args, **kwargs)
#     207     except (TypeError, ValueError):
#     208       # Note: convert_to_eager_tensor currently raises a ValueError, not a
#
# ~/miniconda3/envs/ml/lib/python3.7/site-packages/keras/activations.py in relu(x, alpha, max_value, threshold)
#     309       Tensor will be of the same shape and dtype of input `x`.
#     310   """
# --> 311   return backend.relu(x, alpha=alpha, max_value=max_value, threshold=threshold)
#     312
#     313
#
# ~/miniconda3/envs/ml/lib/python3.7/site-packages/tensorflow/python/util/dispatch.py in wrapper(*args, **kwargs)
#     204     """Call target, and fall back on dispatchers if there is a TypeError."""
#     205     try:
# --> 206       return target(*args, **kwargs)
#     207     except (TypeError, ValueError):
#     208       # Note: convert_to_eager_tensor currently raises a ValueError, not a
#
# ~/miniconda3/envs/ml/lib/python3.7/site-packages/keras/backend.py in relu(x, alpha, max_value, threshold)
#    4710     clip_max = False
#    4711   else:
# -> 4712     x = tf.nn.relu(x)
#    4713
#    4714   if clip_max:
#
# ~/miniconda3/envs/ml/lib/python3.7/site-packages/tensorflow/python/ops/gen_nn_ops.py in relu(features, name)
#   10479       return _result
#   10480     except _core._NotOkStatusException as e:
# > 10481       _ops.raise_from_not_ok_status(e, name)
#   10482     except _core._FallbackException:
#   10483       pass
#
# ~/miniconda3/envs/ml/lib/python3.7/site-packages/tensorflow/python/framework/ops.py in raise_from_not_ok_status(e, name)
#    6939   message = e.message + (" name: " + name if name is not None else "")
#    6940   # pylint: disable=protected-access
# -> 6941   six.raise_from(core._status_to_exception(e.code, message), None)
#    6942   # pylint: enable=protected-access
#    6943
#
# ~/miniconda3/envs/ml/lib/python3.7/site-packages/six.py in raise_from(value, from_value)
#
# ResourceExhaustedError: OOM when allocating tensor with shape[10000,16,16,16,32] and type float on /job:localhost/replica:0/task:0/device:GPU:0 by allocator GPU_0_bfc [Op:Relu]
