# %%
import h5py
import os
import matplotlib.pyplot as plt
import numpy as np

data_path = os.path.join(os.path.expanduser('~'), 'data', '3d-mnist', 
                         'full_dataset_vectors.h5')

assert os.path.isfile(data_path), \
    'Download the 3d-mnist data from https://www.kaggle.com/daavoo/3d-mnist'

with h5py.File(data_path, 'r') as f:
    train_X = np.reshape(f["X_train"][:], (-1, 16, 16, 16, 1))
    train_y = f["y_train"][:]    
    test_X = np.reshape(f["X_test"][:]  , (-1, 16, 16, 16, 1))
    test_y = f["y_test"][:]

train_X = train_X[:,::-1,:,:]
test_X = test_X[:,::-1,:,:]

def onehot(values: np.ndarray) -> np.ndarray:
    encoded = np.zeros((len(values), 10))

    for i in range(len(values)):
        encoded[i,values[i]] = 1

    return encoded

train_y = onehot(train_y)
test_y = onehot(test_y)

for i in range(5):
    fig, ax = plt.subplots(4, 4)
    fig.suptitle(str(np.argmax(train_y[i])))
    ax = ax.ravel()

    for j in range(16):
        ax[j].imshow(train_X[i,:,:,j], cmap='Greys')
        ax[j].axis('off')

    plt.show()

# %%
from tensorflow.keras import Model
from tensorflow.keras.layers import Activation, BatchNormalization, Conv3D, Dense, \
                                    Dropout, Flatten, \
                                    GlobalAveragePooling3D, Input, \
                                    MaxPooling3D
from tensorflow.keras.regularizers import l2

inputs = Input((16, 16, 16, 1), name='inputs')

x = inputs

kernel = (3, 3, 3)
dropout = 0.3
weight_decay = 1e-3
regularizer = l2(weight_decay)

x = Conv3D(32, kernel, padding='SAME', activation=None, 
           kernel_regularizer=regularizer, name='conv1')(x)
x = BatchNormalization(name='norm1')(x)
x = Activation('relu')(x)
x = Conv3D(32, kernel, padding='SAME', activation=None, 
           kernel_regularizer=regularizer, name='conv2')(x)
x = BatchNormalization(name='norm2')(x)
x = Activation('relu')(x)
x = MaxPooling3D((2, 2, 2), name='pool1')(x)
x = Conv3D(64, kernel, padding='SAME', activation=None, 
           kernel_regularizer=regularizer, name='conv3')(x)
x = BatchNormalization(name='norm3')(x)
x = Activation('relu')(x)
x = Conv3D(64, kernel, padding='SAME', activation=None, 
           kernel_regularizer=regularizer, name='conv4')(x)
x = BatchNormalization(name='norm4')(x)
x = Activation('relu')(x)
x = MaxPooling3D((2, 2, 2), name='pool2')(x)
x = Conv3D(128, kernel, padding='SAME', activation=None, 
           kernel_regularizer=regularizer, name='conv5')(x)
x = BatchNormalization(name='norm5')(x)
x = Activation('relu')(x)
x = Conv3D(128, kernel, padding='SAME', activation=None, 
           kernel_regularizer=regularizer, name='conv6')(x)
x = BatchNormalization(name='norm6')(x)
x = MaxPooling3D((2, 2, 2), name='pool3')(x)
x = Conv3D(256, kernel, padding='SAME', activation=None, 
           kernel_regularizer=regularizer, name='conv7')(x)
x = BatchNormalization(name='norm7')(x)
x = Activation('relu')(x)
x = Conv3D(256, kernel, padding='SAME', activation=None, 
           kernel_regularizer=regularizer, name='conv8')(x)
x = BatchNormalization(name='norm8')(x)
x = Activation('relu')(x)
x = GlobalAveragePooling3D(name='pool4')(x)
x = Dropout(dropout)(x)
x = Dense(10, kernel_regularizer=regularizer, activation=None, name='dense')(x)
x = BatchNormalization(name='norm9')(x)
x = Activation('relu')(x)
x = Dropout(dropout)(x)
x = Dense(10, activation='softmax', name='preds')(x)

model = Model(inputs, x)
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# inputs (InputLayer)          [(None, 16, 16, 16, 1)]   0
# _________________________________________________________________
# conv1 (Conv3D)               (None, 16, 16, 16, 32)    896
# _________________________________________________________________
# norm1 (BatchNormalization)   (None, 16, 16, 16, 32)    128
# _________________________________________________________________
# activation (Activation)      (None, 16, 16, 16, 32)    0
# _________________________________________________________________
# conv2 (Conv3D)               (None, 16, 16, 16, 32)    27680
# _________________________________________________________________
# norm2 (BatchNormalization)   (None, 16, 16, 16, 32)    128
# _________________________________________________________________
# activation_1 (Activation)    (None, 16, 16, 16, 32)    0
# _________________________________________________________________
# pool1 (MaxPooling3D)         (None, 8, 8, 8, 32)       0
# _________________________________________________________________
# conv3 (Conv3D)               (None, 8, 8, 8, 64)       55360
# _________________________________________________________________
# norm3 (BatchNormalization)   (None, 8, 8, 8, 64)       256
# _________________________________________________________________
# activation_2 (Activation)    (None, 8, 8, 8, 64)       0
# _________________________________________________________________
# conv4 (Conv3D)               (None, 8, 8, 8, 64)       110656
# _________________________________________________________________
# norm4 (BatchNormalization)   (None, 8, 8, 8, 64)       256
# _________________________________________________________________
# activation_3 (Activation)    (None, 8, 8, 8, 64)       0
# _________________________________________________________________
# pool2 (MaxPooling3D)         (None, 4, 4, 4, 64)       0
# _________________________________________________________________
# conv5 (Conv3D)               (None, 4, 4, 4, 128)      221312
# _________________________________________________________________
# norm5 (BatchNormalization)   (None, 4, 4, 4, 128)      512
# _________________________________________________________________
# activation_4 (Activation)    (None, 4, 4, 4, 128)      0
# _________________________________________________________________
# conv6 (Conv3D)               (None, 4, 4, 4, 128)      442496
# _________________________________________________________________
# norm6 (BatchNormalization)   (None, 4, 4, 4, 128)      512
# _________________________________________________________________
# pool3 (MaxPooling3D)         (None, 2, 2, 2, 128)      0
# _________________________________________________________________
# conv7 (Conv3D)               (None, 2, 2, 2, 256)      884992
# _________________________________________________________________
# norm7 (BatchNormalization)   (None, 2, 2, 2, 256)      1024
# _________________________________________________________________
# activation_5 (Activation)    (None, 2, 2, 2, 256)      0
# _________________________________________________________________
# conv8 (Conv3D)               (None, 2, 2, 2, 256)      1769728
# _________________________________________________________________
# norm8 (BatchNormalization)   (None, 2, 2, 2, 256)      1024
# _________________________________________________________________
# activation_6 (Activation)    (None, 2, 2, 2, 256)      0
# _________________________________________________________________
# pool4 (GlobalAveragePooling3 (None, 256)               0
# _________________________________________________________________
# dropout (Dropout)            (None, 256)               0
# _________________________________________________________________
# dense (Dense)                (None, 10)                2570
# _________________________________________________________________
# norm9 (BatchNormalization)   (None, 10)                40
# _________________________________________________________________
# activation_7 (Activation)    (None, 10)                0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 10)                0
# _________________________________________________________________
# preds (Dense)                (None, 10)                110
# =================================================================
# Total params: 3,519,680
# Trainable params: 3,517,740
# Non-trainable params: 1,940
# _________________________________________________________________
# 2022-03-12 20:40:40.894312: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-03-12 20:40:40.894558: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-03-12 20:40:40.894679: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-03-12 20:40:41.218628: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-03-12 20:40:41.218807: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-03-12 20:40:41.218952: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-03-12 20:40:41.219081: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1510] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 10991 MB memory:  -> device: 0, name: NVIDIA TITAN X (Pascal), pci bus id: 0000:01:00.0, compute capability: 6.1

# %%
from tensorflow.keras.callbacks import ReduceLROnPlateau
from tensorflow.keras.optimizers import Adam

model.compile(loss='categorical_crossentropy', optimizer=Adam(1e-3),
              metrics=['accuracy'])

callbacks = [
    ReduceLROnPlateau(
        monitor="loss",
        factor=0.1,
        patience=5,
        verbose=1
    )
]

model.fit(train_X, train_y, 
          validation_data=(test_X, test_y), 
          epochs=100, 
          batch_size=32, 
          shuffle=True,
          callbacks=callbacks)
# Out:
# 2022-03-12 20:40:42.026123: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:185] None of the MLIR Optimization Passes are enabled (registered 2)
# Epoch 1/100
# 2022-03-12 20:40:43.371977: I tensorflow/stream_executor/cuda/cuda_dnn.cc:369] Loaded cuDNN version 8100
# 2022-03-12 20:40:43.565489: W tensorflow/stream_executor/gpu/asm_compiler.cc:113] *** WARNING *** You are using ptxas 9.1.108, which is older than 9.2.88. ptxas 9.x before 9.2.88 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You do not need to update to CUDA 9.2.88; cherry-picking the ptxas binary is sufficient.
# 313/313 [==============================] - 9s 22ms/step - loss: 2.5740 - accuracy: 0.2812 - val_loss: 2.6373 - val_accuracy: 0.1495
# Epoch 2/100
# 313/313 [==============================] - 7s 21ms/step - loss: 1
100
# 313/313 [==============================] - 7s 23ms/step - loss: 0.4777 - accuracy: 0.9242 - val_loss: 1.0028 - val_accuracy: 0.8310
# Epoch 63/100
# 313/313 [==============================] - 7s 23ms/step - loss: 0.4600 - accuracy: 0.9322 - val_loss: 1.0177 - val_accuracy: 0.8285
# Epoch 64/100
# 313/313 [==============================] - 7s 23ms/step - loss: 0.4635 - accuracy: 0.9258 - val_loss: 1.0205 - val_accuracy: 0.8245
# Epoch 65/100
# 313/313 [==============================] - 7s 23ms/step - loss: 0.4536 - accuracy: 0.9300 - val_loss: 1.0632 - val_accuracy: 0.8205
# Epoch 66/100
# 313/313 [==============================] - 7s 22ms/step - loss: 0.4498 - accuracy: 0.9285 - val_loss: 1.0668 - val_accuracy: 0.8295
# Epoch 67/100
# 313/313 [==============================] - 7s 23ms/step - loss: 0.4377 - accuracy: 0.9338 - val_loss: 1.0216 - val_accuracy: 0.8335
# Epoch 68/100
# 313/313 [==============================] - 7s 22ms/step - loss: 0.4310 - accuracy: 0.9340 - val_loss: 1.0449 - val_accuracy: 0.8245
# Epoch 69/100
# 313/313 [==============================] - 7s 23ms/step - loss: 0.4318 - accuracy: 0.9306 - val_loss: 1.0689 - val_accuracy: 0.8280
# Epoch 70/100
# 313/313 [==============================] - 7s 23ms/step - loss: 0.4204 - accuracy: 0.9344 - val_loss: 1.0710 - val_accuracy: 0.8265
# Epoch 71/100
# 313/313 [==============================] - 7s 22ms/step - loss: 0.4181 - accuracy: 0.9345 - val_loss: 1.0944 - val_accuracy: 0.8210
# Epoch 72/100
# 313/313 [==============================] - 7s 23ms/step - loss: 0.4206 - accuracy: 0.9287 - val_loss: 1.0327 - val_accuracy: 0.8290
# Epoch 73/100
# 313/313 [==============================] - 7s 22ms/step - loss: 0.4025 - accuracy: 0.9373 - val_loss: 1.0567 - val_accuracy: 0.8340
# Epoch 74/100
# 313/313 [==============================] - 7s 23ms/step - loss: 0.4084 - accuracy: 0.9327 - val_loss: 1.0829 - val_accuracy: 0.8240
# Epoch 75/100
# 313/313 [==============================] - 7s 22ms/step - loss: 0.3935 - accuracy: 0.9363 - val_loss: 1.0962 - val_accuracy: 0.8245
# Epoch 76/100
# 313/313 [==============================] - 7s 23ms/step - loss: 0.4038 - accuracy: 0.9301 - val_loss: 1.0411 - val_accuracy: 0.8300
# Epoch 77/100
# 313/313 [==============================] - 7s 23ms/step - loss: 0.4041 - accuracy: 0.9310 - val_loss: 1.0713 - val_accuracy: 0.8200
# Epoch 78/100
# 313/313 [==============================] - 7s 23ms/step - loss: 0.3918 - accuracy: 0.9355 - val_loss: 1.1682 - val_accuracy: 0.8110
# Epoch 79/100
# 313/313 [==============================] - 7s 22ms/step - loss: 0.3990 - accuracy: 0.9320 - val_loss: 1.1823 - val_accuracy: 0.8185
# Epoch 80/100
# 313/313 [==============================] - 7s 22ms/step - loss: 0.3883 - accuracy: 0.9370 - val_loss: 1.1242 - val_accuracy: 0.8160
# Epoch 81/100
# 313/313 [==============================] - 7s 23ms/step - loss: 0.3944 - accuracy: 0.9300 - val_loss: 1.0941 - val_accuracy: 0.8210
# Epoch 82/100
# 313/313 [==============================] - 7s 23ms/step - loss: 0.3806 - accuracy: 0.9345 - val_loss: 1.1018 - val_accuracy: 0.8230
# Epoch 83/100
# 313/313 [==============================] - 7s 22ms/step - loss: 0.3678 - accuracy: 0.9356 - val_loss: 1.0938 - val_accuracy: 0.8225
# Epoch 84/100
# 313/313 [==============================] - 7s 23ms/step - loss: 0.3769 - accuracy: 0.9345 - val_loss: 1.0892 - val_accuracy: 0.8210
# Epoch 85/100
# 313/313 [==============================] - 7s 22ms/step - loss: 0.3716 - accuracy: 0.9336 - val_loss: 1.0903 - val_accuracy: 0.8250
# Epoch 86/100
# 313/313 [==============================] - 7s 23ms/step - loss: 0.3750 - accuracy: 0.9349 - val_loss: 1.1114 - val_accuracy: 0.8270
# Epoch 87/100
# 313/313 [==============================] - 7s 23ms/step - loss: 0.3695 - accuracy: 0.9334 - val_loss: 1.0996 - val_accuracy: 0.8290
# Epoch 88/100
# 313/313 [==============================] - 7s 23ms/step - loss: 0.3633 - accuracy: 0.9391 - val_loss: 1.1802 - val_accuracy: 0.8225
# Epoch 89/100
# 313/313 [==============================] - 7s 22ms/step - loss: 0.3693 - accuracy: 0.9332 - val_loss: 1.1828 - val_accuracy: 0.8255
# Epoch 90/100
# 313/313 [==============================] - 7s 23ms/step - loss: 0.3652 - accuracy: 0.9340 - val_loss: 1.1327 - val_accuracy: 0.8290
# Epoch 91/100
# 313/313 [==============================] - 7s 22ms/step - loss: 0.3648 - accuracy: 0.9315 - val_loss: 1.2060 - val_accuracy: 0.8215
# Epoch 92/100
# 313/313 [==============================] - 7s 23ms/step - loss: 0.3575 - accuracy: 0.9342 - val_loss: 1.1255 - val_accuracy: 0.8235
# Epoch 93/100
# 313/313 [==============================] - 7s 23ms/step - loss: 0.3627 - accuracy: 0.9315 - val_loss: 1.2301 - val_accuracy: 0.8105
# Epoch 94/100
# 313/313 [==============================] - 7s 23ms/step - loss: 0.3518 - accuracy: 0.9354 - val_loss: 1.1678 - val_accuracy: 0.8185
# Epoch 95/100
# 313/313 [==============================] - 7s 23ms/step - loss: 0.3507 - accuracy: 0.9378 - val_loss: 1.2064 - val_accuracy: 0.8150
# Epoch 96/100
# 313/313 [==============================] - 7s 23ms/step - loss: 0.3544 - accuracy: 0.9337 - val_loss: 1.1668 - val_accuracy: 0.8125
# Epoch 97/100
# 313/313 [==============================] - 7s 22ms/step - loss: 0.3473 - accuracy: 0.9380 - val_loss: 1.1983 - val_accuracy: 0.8190
# Epoch 98/100
# 313/313 [==============================] - 7s 22ms/step - loss: 0.3428 - accuracy: 0.9382 - val_loss: 1.1990 - val_accuracy: 0.8175
# Epoch 99/100
# 313/313 [==============================] - 7s 23ms/step - loss: 0.3378 - accuracy: 0.9392 - val_loss: 1.2014 - val_accuracy: 0.8205
# Epoch 100/100
# 313/313 [==============================] - 7s 23ms/step - loss: 0.3394 - accuracy: 0.9367 - val_loss: 1.2208 - val_accuracy: 0.8195

# %%
from explainability import LayerwiseRelevancePropagator

image_idx = 0

explanations = np.zeros((10, 16, 16, 16, 1))
predictions = model.predict(train_X[image_idx:image_idx + 1])
print(f'Predictions: {predictions[0]}')

for i in range(10):
    explainer = LayerwiseRelevancePropagator(model, layer=33, idx=i, alpha=2, beta=1)
    explanations[i] = explainer(train_X[image_idx:image_idx + 1])
    print(f'Sum evidence for {i}: {np.sum(explanations[i])}')
# Out:
# Predictions: [4.1865981e-08 1.4147719e-10 3.2737089e-04 5.7389090e-05 7.1149157e-06
#  9.9907160e-01 1.0164841e-06 4.4236076e-06 5.3075748e-04 1.8444251e-07]
# Sum evidence for 0: -1189.324320614338
# Sum evidence for 1: -1814.0937900543213
# Sum evidence for 2: -216.4915064126253
# Sum evidence for 3: -407.0402839332819
# Sum evidence for 4: -633.205591365695
# Sum evidence for 5: 657.7263321280479
# Sum evidence for 6: -846.1161525249481
# Sum evidence for 7: -685.3609852641821
# Sum evidence for 8: -164.07900226861238
# Sum evidence for 9: -1030.9719504117966

# %%
model.save_weights('/home/esten/tmp_weights.hdf5')

# %%
for i in range(len(explanations)):
    explanations[i] = explanations[i] / np.amax(np.abs(explanations[i]))
    explanations[i] -= explanations[i,0,0,0,0]
    
    fig, ax = plt.subplots(2, 16, figsize=(30, 5))
    fig.suptitle(f'{i} ({round(predictions[0,i], 2)})')
    
    for j in range(16):
        ax[0][j].imshow(train_X[image_idx,:,:,j])
        ax[1][j].imshow(explanations[i,:,:,j], cmap='seismic', clim=(-1, 1))
        ax[0][j].axis('off')
        ax[1][j].axis('off')
        
    plt.show()

# %%
fig, ax = plt.subplots(10, 10, figsize=(20, 20))

for i in range(10):
    for j in range(10):
        ax[i][j].axis('off')
        ax[i][j].imshow(explanations[i,:,:,5] - explanations[j,:,:,5], cmap='seismic', clim=(-1, 1))
        
plt.show()

# %%
layers = [
    (33, 'prediction'),
    (35, 'mask'),
    (36, 'dense')
]

#for i in range(len(explainer.layers)):
#    print(f'{i}: {explainer.layers[i]}')

for layer, description in layers:
    layerwise_explanations = []
    for i in range(1):
        explainer = LayerwiseRelevancePropagator(model, layer=33, idx=i, alpha=1, beta=0)
        layerwise_explanations.append(explainer(train_X[image_idx:]))
        
    print(layerwise_explanations[0].shape)
# Out:
# 2022-03-11 23:11:00.764319: W tensorflow/core/framework/cpu_allocator_impl.cc:80] Allocation of 327680000 exceeds 10% of free system memory.
# 2022-03-11 23:11:00.979159: W tensorflow/core/kernels/gpu_utils.cc:49] Failed to allocate memory for convolution redzone checking; skipping this check. This is benign and only means that we won't check cudnn for out-of-bounds reads and writes. This message will only be printed once.
# 2022-03-11 23:11:11.068557: W tensorflow/core/common_runtime/bfc_allocator.cc:457] Allocator (GPU_0_bfc) ran out of memory trying to allocate 4.88GiB (rounded to 5242880000)requested by op Relu
# If the cause is memory fragmentation maybe the environment variable 'TF_GPU_ALLOCATOR=cuda_malloc_async' will improve the situation.
# Current allocation summary follows.
# Current allocation summary follows.
# 2022-03-11 23:11:11.068643: I tensorflow/core/common_runtime/bfc_allocator.cc:1004] BFCAllocator dump for GPU_0_bfc
# 2022-03-11 23:11:11.068685: I tensorflow/core/common_runtime/bfc_allocator.cc:1011] Bin (256): 	Total Chunks: 160, Chunks in use: 154. 40.0KiB allocated for chunks. 38.5KiB in use in bin. 9.4KiB client-requested in use in bin.
# 2022-03-11 23:11:11.068713: I tensorflow/core/common_runtime/bfc_allocator.cc:1011] Bin (512): 	Total Chunks: 25, Chunks in use: 25. 12.5KiB allocated for chunks. 12.5KiB in use in bin. 12.2KiB client-requested in use in bin.
# 2022-03-11 23:11:11.068738: I tensorflow/core/common_runtime/bfc_allocator.cc:1011] Bin (1024): 	Total Chunks: 24, Chunks in use: 23. 25.0KiB allocated for chunks. 24.0KiB in use in bin. 23.0KiB client-requested in use in bin.
# 2022-03-11 23:11:11.068761: I tensorflow/core/common_runtime/bfc_allocator.cc:1011] Bin (2048): 	Total Chunks: 4, Chunks in use: 4. 14.0KiB allocated for chunks. 14.0KiB in use in bin. 13.5KiB client-requested in use in bin.
# 2022-03-11 23:11:11.068783: I tensorflow/core/common_runtime/bfc_allocator.cc:1011] Bin (4096): 	Total Chunks: 1, Chunks in use: 0. 6.8KiB allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2022-03-11 23:11:11.068806: I tensorflow/core/common_runtime/bfc_allocator.cc:1011] Bin (8192): 	Total Chunks: 4, Chunks in use: 4. 40.0KiB allocated for chunks. 40.0KiB in use in bin. 40.0KiB client-requested in use in bin.
# 2022-03-11 23:11:11.068827: I tensorflow/core/common_runtime/bfc_allocator.cc:1011] Bin (16384): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2022-03-11 23:11:11.068870: I tensorflow/core/common_runtime/bfc_allocator.cc:1011] Bin (32768): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2022-03-11 23:11:11.068897: I tensorflow/core/common_runtime/bfc_allocator.cc:1011] Bin (65536): 	Total Chunks: 3, Chunks in use: 3. 324.0KiB allocated for chunks. 324.0KiB in use in bin. 324.0KiB client-requested in use in bin.
# 2022-03-11 23:11:11.068921: I tensorflow/core/common_runtime/bfc_allocator.cc:1011] Bin (131072): 	Total Chunks: 6, Chunks in use: 5. 1.23MiB allocated for chunks. 1.01MiB in use in bin. 972.0KiB client-requested in use in bin.
# 2022-03-11 23:11:11.068943: I tensorflow/core/common_runtime/bfc_allocator.cc:1011] Bin (262144): 	Total Chunks: 7, Chunks in use: 4. 2.93MiB allocated for chunks. 1.73MiB in use in bin. 1.69MiB client-requested in use in bin.
# 2022-03-11 23:11:11.068965: I tensorflow/core/common_runtime/bfc_allocator.cc:1011] Bin (524288): 	Total Chunks: 4, Chunks in use: 4. 3.46MiB allocated for chunks. 3.46MiB in use in bin. 3.38MiB client-requested in use in bin.
# 2022-03-11 23:11:11.068986: I tensorflow/core/common_runtime/bfc_allocator.cc:1011] Bin (1048576): 	Total Chunks: 4, Chunks in use: 4. 6.75MiB allocated for chunks. 6.75MiB in use in bin. 6.75MiB client-requested in use in bin.
# 2022-03-11 23:11:11.069011: I tensorflow/core/common_runtime/bfc_allocator.cc:1011] Bin (2097152): 	Total Chunks: 4, Chunks in use: 3. 13.47MiB allocated for chunks. 10.12MiB in use in bin. 10.12MiB client-requested in use in bin.
# 2022-03-11 23:11:11.069036: I tensorflow/core/common_runtime/bfc_allocator.cc:1011] Bin (4194304): 	Total Chunks: 5, Chunks in use: 5. 32.06MiB allocated for chunks. 32.06MiB in use in bin. 30.38MiB client-requested in use in bin.
# 2022-03-11 23:11:11.069057: I tensorflow/core/common_runtime/bfc_allocator.cc:1011] Bin (8388608): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2022-03-11 23:11:11.069077: I tensorflow/core/common_runtime/bfc_allocator.cc:1011] Bin (16777216): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2022-03-11 23:11:11.069097: I tensorflow/core/common_runtime/bfc_allocator.cc:1011] Bin (33554432): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2022-03-11 23:11:11.069120: I tensorflow/core/common_runtime/bfc_allocator.cc:1011] Bin (67108864): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2022-03-11 23:11:11.069147: I tensorflow/core/common_runtime/bfc_allocator.cc:1011] Bin (134217728): 	Total Chunks: 2, Chunks in use: 1. 308.59MiB allocated for chunks. 156.25MiB in use in bin. 156.25MiB client-requested in use in bin.
# 2022-03-11 23:11:11.069172: I tensorflow/core/common_runtime/bfc_allocator.cc:1011] Bin
I tensorflow/core/common_runtime/bfc_allocator.cc:1068] 3 Chunks of size 442368 totalling 1.27MiB
# 2022-03-11 23:11:11.073710: I tensorflow/core/common_runtime/bfc_allocator.cc:1068] 1 Chunks of size 484608 totalling 473.2KiB
# 2022-03-11 23:11:11.073729: I tensorflow/core/common_runtime/bfc_allocator.cc:1068] 3 Chunks of size 884736 totalling 2.53MiB
# 2022-03-11 23:11:11.073748: I tensorflow/core/common_runtime/bfc_allocator.cc:1068] 1 Chunks of size 975872 totalling 953.0KiB
# 2022-03-11 23:11:11.073767: I tensorflow/core/common_runtime/bfc_allocator.cc:1068] 4 Chunks of size 1769472 totalling 6.75MiB
# 2022-03-11 23:11:11.073786: I tensorflow/core/common_runtime/bfc_allocator.cc:1068] 3 Chunks of size 3538944 totalling 10.12MiB
# 2022-03-11 23:11:11.073805: I tensorflow/core/common_runtime/bfc_allocator.cc:1068] 1 Chunks of size 5305344 totalling 5.06MiB
# 2022-03-11 23:11:11.073823: I tensorflow/core/common_runtime/bfc_allocator.cc:1068] 4 Chunks of size 7077888 totalling 27.00MiB
# 2022-03-11 23:11:11.073843: I tensorflow/core/common_runtime/bfc_allocator.cc:1068] 1 Chunks of size 163840000 totalling 156.25MiB
# 2022-03-11 23:11:11.073865: I tensorflow/core/common_runtime/bfc_allocator.cc:1068] 1 Chunks of size 327680000 totalling 312.50MiB
# 2022-03-11 23:11:11.073885: I tensorflow/core/common_runtime/bfc_allocator.cc:1068] 2 Chunks of size 5242880000 totalling 9.77GiB
# 2022-03-11 23:11:11.073904: I tensorflow/core/common_runtime/bfc_allocator.cc:1072] Sum Total of in-use chunks: 10.28GiB
# 2022-03-11 23:11:11.073922: I tensorflow/core/common_runtime/bfc_allocator.cc:1074] total_region_allocated_bytes_: 11606360064 memory_limit_: 11606360064 available bytes: 0 curr_region_allocation_bytes_: 23212720128
# 2022-03-11 23:11:11.073950: I tensorflow/core/common_runtime/bfc_allocator.cc:1080] Stats:
# Limit:                     11606360064
# InUse:                     11035554560
# MaxInUse:                  11035561472
# NumAllocs:                    10407149
# MaxAllocSize:               5242880000
# Reserved:                            0
# PeakReserved:                        0
# LargestFreeBlock:                    0
#
# 2022-03-11 23:11:11.074010: W tensorflow/core/common_runtime/bfc_allocator.cc:468] *************************************************************************************************___
# 2022-03-11 23:11:11.074101: W tensorflow/core/framework/op_kernel.cc:1692] OP_REQUIRES failed at numeric_op.h:61 : Resource exhausted: OOM when allocating tensor with shape[10000,16,16,16,32] and type float on /job:localhost/replica:0/task:0/device:GPU:0 by allocator GPU_0_bfc
# ---------------------------------------------------------------------------
# ResourceExhaustedError                    Traceback (most recent call last)
# /tmp/ipykernel_32590/2515086044.py in <module>
#      12     for i in range(1):
#      13         explainer = LayerwiseRelevancePropagator(model, layer=33, idx=i, alpha=1, beta=0)
# ---> 14         layerwise_explanations.append(explainer(train_X[image_idx:]))
#      15
#      16     print(layerwise_explanations[0].shape)
#
# ~/miniconda3/envs/ml/lib/python3.7/site-packages/keras/engine/base_layer.py in __call__(self, *args, **kwargs)
#    1035         with autocast_variable.enable_auto_cast_variables(
#    1036             self._compute_dtype_object):
# -> 1037           outputs = call_fn(inputs, *args, **kwargs)
#    1038
#    1039         if self._activity_regularizer:
#
# ~/miniconda3/envs/ml/lib/python3.7/site-packages/keras/engine/functional.py in call(self, inputs, training, mask)
#     413     """
#     414     return self._run_internal_graph(
# --> 415         inputs, training=training, mask=mask)
#     416
#     417   def compute_output_shape(self, input_shape):
#
# ~/miniconda3/envs/ml/lib/python3.7/site-packages/keras/engine/functional.py in _run_internal_graph(self, inputs, training, mask)
#     548
#     549         args, kwargs = node.map_arguments(tensor_dict)
# --> 550         outputs = node.layer(*args, **kwargs)
#     551
#     552         # Update tensor_dict.
#
# ~/miniconda3/envs/ml/lib/python3.7/site-packages/keras/engine/base_layer.py in __call__(self, *args, **kwargs)
#    1035         with autocast_variable.enable_auto_cast_variables(
#    1036             self._compute_dtype_object):
# -> 1037           outputs = call_fn(inputs, *args, **kwargs)
#    1038
#    1039         if self._activity_regularizer:
#
# ~/miniconda3/envs/ml/lib/python3.7/site-packages/keras/layers/core.py in call(self, inputs)
#     420
#     421   def call(self, inputs):
# --> 422     return self.activation(inputs)
#     423
#     424   def compute_output_shape(self, input_shape):
#
# ~/miniconda3/envs/ml/lib/python3.7/site-packages/tensorflow/python/util/dispatch.py in wrapper(*args, **kwargs)
#     204     """Call target, and fall back on dispatchers if there is a TypeError."""
#     205     try:
# --> 206       return target(*args, **kwargs)
#     207     except (TypeError, ValueError):
#     208       # Note: convert_to_eager_tensor currently raises a ValueError, not a
#
# ~/miniconda3/envs/ml/lib/python3.7/site-packages/keras/activations.py in relu(x, alpha, max_value, threshold)
#     309       Tensor will be of the same shape and dtype of input `x`.
#     310   """
# --> 311   return backend.relu(x, alpha=alpha, max_value=max_value, threshold=threshold)
#     312
#     313
#
# ~/miniconda3/envs/ml/lib/python3.7/site-packages/tensorflow/python/util/dispatch.py in wrapper(*args, **kwargs)
#     204     """Call target, and fall back on dispatchers if there is a TypeError."""
#     205     try:
# --> 206       return target(*args, **kwargs)
#     207     except (TypeError, ValueError):
#     208       # Note: convert_to_eager_tensor currently raises a ValueError, not a
#
# ~/miniconda3/envs/ml/lib/python3.7/site-packages/keras/backend.py in relu(x, alpha, max_value, threshold)
#    4710     clip_max = False
#    4711   else:
# -> 4712     x = tf.nn.relu(x)
#    4713
#    4714   if clip_max:
#
# ~/miniconda3/envs/ml/lib/python3.7/site-packages/tensorflow/python/ops/gen_nn_ops.py in relu(features, name)
#   10479       return _result
#   10480     except _core._NotOkStatusException as e:
# > 10481       _ops.raise_from_not_ok_status(e, name)
#   10482     except _core._FallbackException:
#   10483       pass
#
# ~/miniconda3/envs/ml/lib/python3.7/site-packages/tensorflow/python/framework/ops.py in raise_from_not_ok_status(e, name)
#    6939   message = e.message + (" name: " + name if name is not None else "")
#    6940   # pylint: disable=protected-access
# -> 6941   six.raise_from(core._status_to_exception(e.code, message), None)
#    6942   # pylint: enable=protected-access
#    6943
#
# ~/miniconda3/envs/ml/lib/python3.7/site-packages/six.py in raise_from(value, from_value)
#
# ResourceExhaustedError: OOM when allocating tensor with shape[10000,16,16,16,32] and type float on /job:localhost/replica:0/task:0/device:GPU:0 by allocator GPU_0_bfc [Op:Relu]
