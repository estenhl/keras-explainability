# %%
import matplotlib.pyplot as plt
import numpy as np

from sklearn.metrics.pairwise import euclidean_distances
from sklearn.preprocessing import OneHotEncoder
from typing import Tuple


np.random.seed(42)

def generate_square(shape: Tuple[int] = (16, 16, 16)) -> np.ndarray:
    img = np.zeros(shape)
    corner = np.asarray(shape) // 4 + np.random.randint(0, shape[0] // 2, 3)
    side = np.random.randint(shape[1] / 3, shape[1] * 2 / 3)
    
    idx = np.asarray(np.meshgrid(*[np.arange(side) for _ in range(3)])).T.reshape(-1, 3)
    idx += corner
    maxes = np.amax(idx, axis=-1)
    idx = idx[maxes < shape[0]]
    
    img[tuple(idx.T)] = 1
    
    return img

def generate_circle(shape: Tuple[int] = (16, 16, 16)) -> np.ndarray:
    img = np.zeros(shape)
    center = np.random.randint(0, shape[0], 3)
    radius = np.random.randint(shape[0] // 4, shape[0] // 2)

    idx = np.asarray(np.meshgrid(*[np.arange(x) for x in shape])).T.reshape(-1, 3)
    distances = euclidean_distances(idx, center.reshape(1, -1))[:,0]
    inside = distances <= radius
    
    img[tuple(idx[inside].T)] = 1
    
    return img

def generate_noise(shape: Tuple[int] = (16, 16, 16)) -> np.ndarray:
    return np.random.uniform(0, 1, shape)

n = 200
shape = 16
squares = np.asarray([generate_square(shape=(shape, shape, shape)) for _ in range(n)])
circles = np.asarray([generate_circle(shape=(shape, shape, shape)) for _ in range(n)])
noise = np.asarray([generate_noise(shape=(shape, shape, shape)) for _ in range(n)])
X = np.concatenate([squares, circles, noise], axis=0)
y = np.asarray((['square'] * n) + (['circle'] * n) + (['noise'] * n))
idx = np.random.permutation(np.arange(len(X)))
X = np.reshape(X, (-1, shape, shape, shape, 1))
X = X[idx]
y = y[idx]

print(f'X.shape: {X.shape}')
print(f'y.shape: {y.shape}')

for i in range(10):
    fig, ax = plt.subplots(1, shape, figsize=(15, 2))
    fig.suptitle(y[i])
    for j in range(shape):
        ax[j].imshow(X[i,j], cmap='Greys_r')
        ax[j].axis('off')
    plt.show()

encoder = OneHotEncoder()
y = encoder.fit_transform(y.reshape(-1, 1)).toarray()

train_X = X[:300]
train_y = y[:300]
test_X = X[:300]
test_y = y[:300]
# Out:
# X.shape: (600, 16, 16, 16, 1)
# y.shape: (600,)

# %%
from tensorflow.keras import Model
from tensorflow.keras.layers import Activation, BatchNormalization, Conv3D, Dense, Dropout, \
                                    Flatten, GlobalAveragePooling3D, Input, MaxPooling3D, Reshape
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.regularizers import l2

input = Input((shape, shape, shape, 1))
x = input

x = Conv3D(8, (3, 3, 3), padding='SAME', activation=None, kernel_regularizer=l2(1e-3))(x)
x = BatchNormalization()(x)
x = Activation('relu')(x)
x = MaxPooling3D((2, 2, 2))(x)

x = Conv3D(16, (3, 3, 3), padding='SAME', activation=None, kernel_regularizer=l2(1e-3))(x)
x = BatchNormalization()(x)
x = Activation('relu')(x)
x = MaxPooling3D((2, 2, 2))(x)

x = Conv3D(32, (3, 3, 3), padding='SAME', activation=None, kernel_regularizer=l2(1e-3))(x)
x = BatchNormalization()(x)
x = Activation('relu')(x)
x = MaxPooling3D((2, 2, 2))(x)

x = Conv3D(32, (3, 3, 3), padding='SAME', activation=None, kernel_regularizer=l2(1e-3))(x)
x = BatchNormalization()(x)
x = Activation('relu')(x)
x = MaxPooling3D((2, 2, 2))(x)

x = Flatten()(x)
x = Dropout(0.5)(x)
x = Dense(3, activation='softmax')(x)

model = Model(input, x)

model.compile(loss='categorical_crossentropy', optimizer=Adam(1e-4), metrics=['accuracy'])

model.fit(train_X, train_y, validation_data=(test_X, test_y), batch_size=32, epochs=100)
# Out:
# Epoch 1/100
# 10/10 [==============================] - 1s 25ms/step - loss: 2.2797 - accuracy: 0.3467 - val_loss: 1.1439 - val_accuracy: 0.3300
# Epoch 2/100
# 10/10 [==============================] - 0s 9ms/step - loss: 1.4713 - accuracy: 0.5500 - val_loss: 1.1093 - val_accuracy: 0.7867
# Epoch 3/100
# 10/10 [==============================] - 0s 9ms/step - loss: 1.0479 - accuracy: 0.6267 - val_loss: 1.0952 - val_accuracy: 0.5700
# Epoch 4/100
# 10/10 [==============================] - 0s 11ms/step - loss: 0.9742 - accuracy: 0.6667 - val_loss: 1.0948 - val_accuracy: 0.4833
# Epoch 5/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.7881 - accuracy: 0.7233 - val_loss: 1.0998 - val_accuracy: 0.4567
# Epoch 6/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.6667 - accuracy: 0.7500 - val_loss: 1.1090 - val_accuracy: 0.4767
# Epoch 7/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.6678 - accuracy: 0.7633 - val_loss: 1.1168 - val_accuracy: 0.4867
# Epoch 8/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.5900 - accuracy: 0.7800 - val_loss: 1.1266 - val_accuracy: 0.5100
# Epoch 9/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.5819 - accuracy: 0.7867 - val_loss: 1.1407 - val_accuracy: 0.5167
# Epoch 10/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.5736 - accuracy: 0.7933 - val_loss: 1.1553 - val_accuracy: 0.5667
# Epoch 11/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.4948 - accuracy: 0.8133 - val_loss: 1.1734 - val_accuracy: 0.5667
# Epoch 12/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.5375 - accuracy: 0.7900 - val_loss: 1.1827 - val_accuracy: 0.5733
# Epoch 13/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.4859 - accuracy: 0.8233 - val_loss: 1.1911 - val_accuracy: 0.5767
# Epoch 14/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.4801 - accuracy: 0.8300 - val_loss: 1.1992 - val_accuracy: 0.5633
# Epoch 15/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.4747 - accuracy: 0.8167 - val_loss: 1.2122 - val_accuracy: 0.5633
# Epoch 16/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.4322 - accuracy: 0.8633 - val_loss: 1.2250 - val_accuracy: 0.5433
# Epoch 17/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.3946 - accuracy: 0.8867 - val_loss: 1.2272 - val_accuracy: 0.5433
# Epoch 18/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.4214 - accuracy: 0.8467 - val_loss: 1.2282 - val_accuracy: 0.5533
# Epoch 19/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.4083 - accuracy: 0.8533 - val_loss: 1.2297 - val_accuracy: 0.5667
# Epoch 20/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.3544 - accuracy: 0.8900 - val_loss: 1.2340 - val_accuracy: 0.5700
# Epoch 21/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.3861 - accuracy: 0.8800 - val_loss: 1.2322 - val_accuracy: 0.5667
# Epoch 22/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.4273 - accuracy: 0.8667 - val_loss: 1.2087 - val_accuracy: 0.5667
# Epoch 23/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.3446 - accuracy: 0.9067 - val_loss: 1.1923 - val_accuracy: 0.5667
# Epoch 24/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.3484 - accuracy: 0.8933 - val_loss: 1.1763 - val_accuracy: 0.5667
# Epoch 25/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.3352 - accuracy: 0.9033 - val_loss: 1.1554 - val_accuracy: 0.5667
# Epoch 26/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.3428 - accuracy: 0.9100 - val_loss: 1.1283 - val_accuracy: 0.5733
# Epoch 27/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.3147 - accuracy: 0.9033 - val_loss: 1.0757 - val_accuracy: 0.5833
# Epoch 28/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.3262 - accuracy: 0.9167 - val_loss: 1.0346 - val_accuracy: 0.5800
# Epoch 29/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.2893 - accuracy: 0.9300 - val_loss: 0.9525 - val_accuracy: 0.5767
# Epoch 30/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.3249 - accuracy: 0.8900 - val_loss: 0.8706 - val_accuracy: 0.5867
# Epoch 31/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.2812 - accuracy: 0.9233 - val_loss: 0.7969 - val_accuracy: 0.5800
# Epoch 32/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.3389 - accuracy: 0.8833 - val_loss: 0.7247 - val_accuracy: 0.5933
# Epoch 33/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.2544 - accuracy: 0.9267 - val_loss: 0.6338 - val_accuracy: 0.6500
# Epoch 34/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.2521 - accuracy: 0.9367 - val_loss: 0.5754 - val_accuracy: 0.7700
# Epoch 35/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.2728 - accuracy: 0.9133 - val_loss: 0.5103 - val_accuracy: 0.9067
# Epoch 36/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.2443 - accuracy: 0.9500 - val_loss: 0.4453 - val_accuracy: 0.9333
# Epoch 37/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.2384 - accuracy: 0.9500 - val_loss: 0.4043 - val_accuracy: 0.9333
# Epoch 38/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.2360 - accuracy: 0.9267 - val_loss: 0.3645 - val_accuracy: 0.9400
# Epoch 39/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.2544 - accuracy: 0.9233 - val_loss: 0.3309 - val_accuracy: 0.9433
# Epoch 40/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.2316 - accuracy: 0.9400 - val_loss: 0.3006 - val_accuracy: 0.9500
# Epoch 41/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.2165 - accuracy: 0.9567 - val_loss: 0.2698 - val_accuracy: 0.9533
# Epoch 42/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.2014 - accuracy: 0.9533 - val_loss: 0.2478 - val_accuracy: 0.9600
# Epoch 43/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.2441 - accuracy: 0.9367 - val_loss: 0.2244 - val_accuracy: 0.9600
# Epoch 44/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.1977 - accuracy: 0.9633 - val_loss: 0.2090 - val_accuracy: 0.9600
# Epoch 45/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.2384 - accuracy: 0.9333 - val_loss: 0.1920 - val_accuracy: 0.9667
# Epoch 46/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.1830 - accuracy: 0.9667 - val_loss: 0.1825 - val_accuracy: 0.9667
# Epoch 47/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.2275 - accuracy: 0.9467 - val_loss: 0.1708 - val_accuracy: 0.9767
# Epoch 48/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.1783 - accuracy: 0.9700 - val_loss: 0.1691 - val_accuracy: 0.9700
# Epoch 49/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.1840 - accuracy: 0.9633 - val_loss: 0.1584 - val_accuracy: 0.9767
# Epoch 50/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.2464 - accuracy: 0.9267 - val_loss: 0.1487 - val_accuracy: 0.9867
# Epoch 51/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.1657 - accuracy: 0.9733 - val_loss: 0.1409 - val_accuracy: 0.9867
# Epoch 52/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.2073 - accuracy: 0.9500 - val_loss: 0.1342 - val_accuracy: 0.9933
# Epoch 53/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.1852 - accuracy: 0.9633 - val_loss: 0.1294 - val_accuracy: 0.9933
# Epoch 54/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.1842 - accuracy: 0.9633 - val_loss: 0.1250 - val_accuracy: 0.9933
# Epoch 55/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.1688 - accuracy: 0.9667 - val_loss: 0.1210 - val_accuracy: 0.9967
# Epoch 56/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.2037 - accuracy: 0.9533 - val_loss: 0.1181 - val_accuracy: 1.0000
# Epoch 57/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.1656 - accuracy: 0.9767 - val_loss: 0.1156 - val_accuracy: 1.0000
# Epoch 58/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.1891 - accuracy: 0.9600 - val_loss: 0.1127 - val_accuracy: 1.0000
# Epoch 59/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.1991 - accuracy: 0.9533 - val_loss: 0.1112 - val_accuracy: 1.0000
# Epoch 60/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.1816 - accuracy: 0.9633 - val_loss: 0.1088 - val_accuracy: 1.0000
# Epoch 61/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.1777 - accuracy: 0.9767 - val_loss: 0.1055 - val_accuracy: 1.0000
# Epoch 62/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.1673 - accuracy: 0.9767 - val_loss: 0.1041 - val_accuracy: 1.0000
# Epoch 63/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.1756 - accuracy: 0.9600 - val_loss: 0.1033 - val_accuracy: 1.0000
# Epoch 64/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.1870 - accuracy: 0.9633 - val_loss: 0.1009 - val_accuracy: 1.0000
# Epoch 65/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.1610 - accuracy: 0.9733 - val_loss: 0.0964 - val_accuracy: 1.0000
# Epoch 66/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.1327 - accuracy: 0.9900 - val_loss: 0.0935 - val_accuracy: 1.0000
# Epoch 67/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.1515 - accuracy: 0.9733 - val_loss: 0.0918 - val_accuracy: 1.0000
# Epoch 68/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.1258 - accuracy: 0.9900 - val_loss: 0.0913 - val_accuracy: 1.0000
# Epoch 69/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.1544 - accuracy: 0.9667 - val_loss: 0.0902 - val_accuracy: 1.0000
# Epoch 70/100
# 10/10 [==============================] - 0s 11ms/step - loss: 0.1439 - accuracy: 0.9733 - val_loss: 0.0893 - val_accuracy: 1.0000
# Epoch 71/100
# 10/10 [==============================] - 0s 10ms/step - loss: 0.1384 - accuracy: 0.9733 - val_loss: 0.0883 - val_accuracy: 1.0000
# Epoch 72/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.1326 - accuracy: 0.9900 - val_loss: 0.0868 - val_accuracy: 1.0000
# Epoch 73/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.1214 - accuracy: 0.9933 - val_loss: 0.0860 - val_accuracy: 1.0000
# Epoch 74/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.1308 - accuracy: 0.9933 - val_loss: 0.0850 - val_accuracy: 1.0000
# Epoch 75/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.1620 - accuracy: 0.9800 - val_loss: 0.0846 - val_accuracy: 1.0000
# Epoch 76/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.1303 - accuracy: 0.9867 - val_loss: 0.0844 - val_accuracy: 1.0000
# Epoch 77/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.1236 - accuracy: 0.9967 - val_loss: 0.0841 - val_accuracy: 1.0000
# Epoch 78/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.1237 - accuracy: 0.9867 - val_loss: 0.0827 - val_accuracy: 1.0000
# Epoch 79/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.1434 - accuracy: 0.9733 - val_loss: 0.0823 - val_accuracy: 1.0000
# Epoch 80/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.1485 - accuracy: 0.9800 - val_loss: 0.0825 - val_accuracy: 1.0000
# Epoch 81/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.1388 - accuracy: 0.9733 - val_loss: 0.0816 - val_accuracy: 1.0000
# Epoch 82/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.1395 - accuracy: 0.9867 - val_loss: 0.0803 - val_accuracy: 1.0000
# Epoch 83/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.1255 - accuracy: 0.9733 - val_loss: 0.0799 - val_accuracy: 1.0000
# Epoch 84/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.1376 - accuracy: 0.9800 - val_loss: 0.0785 - val_accuracy: 1.0000
# Epoch 85/100
# 10/10 [==============================] - 0s 10ms/step - loss: 0.1108 - accuracy: 0.9900 - val_loss: 0.0780 - val_accuracy: 1.0000
# Epoch 86/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.1247 - accuracy: 0.9867 - val_loss: 0.0773 - val_accuracy: 1.0000
# Epoch 87/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.1037 - accuracy: 0.9967 - val_loss: 0.0771 - val_accuracy: 1.0000
# Epoch 88/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.1236 - accuracy: 0.9833 - val_loss: 0.0765 - val_accuracy: 1.0000
# Epoch 89/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.1340 - accuracy: 0.9800 - val_loss: 0.0758 - val_accuracy: 1.0000
# Epoch 90/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.1190 - accuracy: 0.9867 - val_loss: 0.0755 - val_accuracy: 1.0000
# Epoch 91/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.1067 - accuracy: 0.9900 - val_loss: 0.0750 - val_accuracy: 1.0000
# Epoch 92/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.1084 - accuracy: 0.9900 - val_loss: 0.0746 - val_accuracy: 1.0000
# Epoch 93/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.1244 - accuracy: 0.9833 - val_loss: 0.0747 - val_accuracy: 1.0000
# Epoch 94/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.1169 - accuracy: 0.9900 - val_loss: 0.0745 - val_accuracy: 1.0000
# Epoch 95/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0996 - accuracy: 1.0000 - val_loss: 0.0739 - val_accuracy: 1.0000
# Epoch 96/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0942 - accuracy: 1.0000 - val_loss: 0.0730 - val_accuracy: 1.0000
# Epoch 97/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.1263 - accuracy: 0.9800 - val_loss: 0.0725 - val_accuracy: 1.0000
# Epoch 98/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.1231 - accuracy: 0.9800 - val_loss: 0.0723 - val_accuracy: 1.0000
# Epoch 99/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.1108 - accuracy: 0.9900 - val_loss: 0.0717 - val_accuracy: 1.0000
# Epoch 100/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.1206 - accuracy: 0.9867 - val_loss: 0.0721 - val_accuracy: 1.0000

# %%
from explainability import LayerwiseRelevancePropagator


explainers = {
    encoder.categories_[0][i]: LayerwiseRelevancePropagator(model, layer=32, idx=i, alpha=2, beta=1) \
    for i in range(3)
}

# %%
for i in range(10):
    img = test_X[i]
    label = encoder.categories_[0][np.argmax(test_y[i])]

    fig, ax = plt.subplots(1, shape, figsize=(15, 2))
    fig.suptitle(f'Image {label}')
    for i in range(shape):
        ax[i].imshow(img[i], cmap='Greys_r')
        ax[i].axis('off')
    plt.show()

    for classname in encoder.categories_[0]:
        explanation = explainers[classname].predict(np.expand_dims(img, axis=0))
        explanation = explanation / np.amax(np.abs(explanation))

        fig, ax = plt.subplots(1, shape, figsize=(15, 2))
        fig.suptitle(f'{classname} explanation')
        for j in range(shape):
            ax[j].imshow(explanation[0,j], cmap='seismic', clim=(-1, 1))
            ax[j].axis('off')
        plt.show()

# %%
from scipy.spatial.distance import euclidean


labels = encoder.categories_[0]

square = np.zeros((16, 16, 16, 1))
square[4:12,4:12,4:12,0] = 1

fig, ax = plt.subplots(1, shape, figsize=(15, 2))
fig.suptitle('Square')
for j in range(shape):
    ax[j].imshow(square[j], cmap='Greys_r')
    ax[j].axis('off')
plt.show()

circle = np.zeros((16, 16, 16, 1))
center = (8, 8, 8)
radius = 4

for i in range(16):
    for j in range(16):
        for k in range(16):
            if euclidean((i, j, k), center) <= radius:
                circle[i,j,k,0] = 1
                
fig, ax = plt.subplots(1, shape, figsize=(15, 2))
fig.suptitle('Circle')
for j in range(shape):
    ax[j].imshow(circle[j], cmap='Greys_r')
    ax[j].axis('off')
plt.show()

combinations = [
    np.concatenate([square[:8], circle[8:]], axis=0),
    np.concatenate([circle[:8], square[8:]], axis=0),
    np.concatenate([square[:,:8], circle[:,8:]], axis=1),
    np.concatenate([circle[:,:8], square[:,8:]], axis=1),
    np.concatenate([square[:,:,:8], circle[:,:,8:]], axis=2),
    np.concatenate([circle[:,:,:8], square[:,:,8:]], axis=2),
]

for i in range(len(combinations)):
    fig, ax = plt.subplots(1, shape, figsize=(15, 2))
    prediction = model.predict(np.expand_dims(combinations[i], axis=0))[0]
    fig.suptitle(' '.join([f'{labels[i]}: {prediction[0]:.2f}' for i in range(len(labels))]))
    
    for j in range(shape):
        ax[j].imshow(combinations[i][j], cmap='Greys_r')
        ax[j].axis('off')
        
    plt.show()
        
    for j in range(3):
        fig, ax = plt.subplots(1, shape, figsize=(15, 2))
        classname = encoder.categories_[0][j]
        explanation = explainers[classname].predict(np.expand_dims(combinations[i], axis=0))[0]
        explanation = explanation / np.amax(np.abs(explanation))
        fig.suptitle(f'{classname} explanation')
        
        for k in range(shape):
            ax[k].imshow(explanation[k], cmap='seismic', clim=(-1, 1))
            ax[k].axis('off')
            
        plt.show()
        
    square_explanation = explainers['square'].predict(np.expand_dims(combinations[i], axis=0))[0]
    square_explanation = square_explanation - np.amin(square_explanation)
    square_explanation = square_explanation / np.amax(square_explanation)
    circle_explanation = explainers['circle'].predict(np.expand_dims(combinations[i], axis=0))[0]
    circle_explanation = circle_explanation - np.amin(circle_explanation)
    circle_explanation = circle_explanation / np.amax(circle_explanation)
    absolute_difference = square_explanation - circle_explanation
    
    fig, ax = plt.subplots(1, shape, figsize=(15, 2))
    fig.suptitle('Absolute difference')

    for j in range(shape):
        ax[j].imshow(absolute_difference[j], cmap='seismic', clim=(-1, 1))
        ax[j].axis('off')

    plt.show()

# %%
print(len(model.layers))
