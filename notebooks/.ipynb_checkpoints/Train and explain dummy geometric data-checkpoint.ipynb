# %%
import matplotlib.pyplot as plt
import numpy as np

from sklearn.metrics.pairwise import euclidean_distances
from sklearn.preprocessing import OneHotEncoder
from typing import Tuple


np.random.seed(42)

def generate_square(shape: Tuple[int] = (16, 16, 16)) -> np.ndarray:
    img = np.zeros(shape)
    corner = np.asarray(shape) // 4 + np.random.randint(0, shape[0] // 2, 3)
    side = np.random.randint(shape[1] / 3, shape[1] * 2 / 3)
    
    idx = np.asarray(np.meshgrid(*[np.arange(side) for _ in range(3)])).T.reshape(-1, 3)
    idx += corner
    maxes = np.amax(idx, axis=-1)
    idx = idx[maxes < shape[0]]
    
    img[tuple(idx.T)] = 1
    
    return img

def generate_circle(shape: Tuple[int] = (16, 16, 16)) -> np.ndarray:
    img = np.zeros(shape)
    center = np.random.randint(0, shape[0], 3)
    radius = np.random.randint(shape[0] // 4, shape[0] // 2)

    idx = np.asarray(np.meshgrid(*[np.arange(x) for x in shape])).T.reshape(-1, 3)
    distances = euclidean_distances(idx, center.reshape(1, -1))[:,0]
    inside = distances <= radius
    
    img[tuple(idx[inside].T)] = 1
    
    return img

def generate_noise(shape: Tuple[int] = (16, 16, 16)) -> np.ndarray:
    return np.random.uniform(0, 1, shape)

n = 200
shape = 16
squares = np.asarray([generate_square(shape=(shape, shape, shape)) for _ in range(n)])
circles = np.asarray([generate_circle(shape=(shape, shape, shape)) for _ in range(n)])
noise = np.asarray([generate_noise(shape=(shape, shape, shape)) for _ in range(n)])
X = np.concatenate([squares, circles, noise], axis=0)
y = np.asarray((['square'] * n) + (['circle'] * n) + (['noise'] * n))
idx = np.random.permutation(np.arange(len(X)))
X = np.reshape(X, (-1, shape, shape, shape, 1))
X = X[idx]
y = y[idx]

print(f'X.shape: {X.shape}')
print(f'y.shape: {y.shape}')

for i in range(10):
    fig, ax = plt.subplots(1, shape, figsize=(15, 2))
    fig.suptitle(y[i])
    for j in range(shape):
        ax[j].imshow(X[i,j], cmap='Greys_r')
        ax[j].axis('off')
    plt.show()

encoder = OneHotEncoder()
y = encoder.fit_transform(y.reshape(-1, 1)).toarray()

train_X = X[:300]
train_y = y[:300]
test_X = X[:300]
test_y = y[:300]
# Out:
# X.shape: (600, 16, 16, 16, 1)
# y.shape: (600,)

# %%
from tensorflow.keras import Model
from tensorflow.keras.layers import Activation, BatchNormalization, Conv3D, Dense, Dropout, \
                                    Flatten, GlobalAveragePooling3D, Input, MaxPooling3D, Reshape
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.regularizers import l2

input = Input((shape, shape, shape, 1))
x = input

x = Conv3D(8, (3, 3, 3), padding='SAME', activation=None, kernel_regularizer=l2(1e-3))(x)
x = BatchNormalization()(x)
x = Activation('relu')(x)
x = MaxPooling3D((2, 2, 2))(x)

x = Conv3D(16, (3, 3, 3), padding='SAME', activation=None, kernel_regularizer=l2(1e-3))(x)
x = BatchNormalization()(x)
x = Activation('relu')(x)
x = MaxPooling3D((2, 2, 2))(x)

x = Conv3D(32, (3, 3, 3), padding='SAME', activation=None, kernel_regularizer=l2(1e-3))(x)
x = BatchNormalization()(x)
x = Activation('relu')(x)
x = MaxPooling3D((2, 2, 2))(x)

x = Conv3D(32, (3, 3, 3), padding='SAME', activation=None, kernel_regularizer=l2(1e-3))(x)
x = BatchNormalization()(x)
x = Activation('relu')(x)
x = MaxPooling3D((2, 2, 2))(x)

x = Flatten()(x)
x = Dropout(0.5)(x)
x = Dense(3, activation='softmax')(x)

model = Model(input, x)

model.compile(loss='categorical_crossentropy', optimizer=Adam(1e-4), metrics=['accuracy'])

model.fit(train_X, train_y, validation_data=(test_X, test_y), batch_size=32, epochs=100)
# Out:
# 2022-03-13 11:26:11.790404: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-03-13 11:26:11.797162: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-03-13 11:26:11.797484: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-03-13 11:26:11.798455: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-03-13 11:26:11.798817: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-03-13 11:26:11.799154: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-03-13 11:26:11.799494: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-03-13 11:26:12.207541: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-03-13 11:26:12.207733: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-03-13 11:26:12.207884: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-03-13 11:26:12.208008: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1510] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 11069 MB memory:  -> device: 0, name: NVIDIA TITAN X (Pascal), pci bus id: 0000:01:00.0, compute capability: 6.1
# 2022-03-13 11:26:12.674555: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:185] None of the MLIR Optimization Passes are enabled (registered 2)
# Epoch 1/100
# 2022-03-13 11:26:13.490556: I tensorflow/stream_executor/cuda/cuda_dnn.cc:369] Loaded cuDNN version 8100
# 2022-03-13 11:26:13.678549: W tensorflow/stream_executor/gpu/asm_compiler.cc:113] *** WARNING *** You are using ptxas 9.1.108, which is older than 9.2.88. ptxas 9.x before 9.2.88 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You do not need to update to CUDA 9.2.88; cherry-picking the ptxas binary is sufficient.
# 10/10 [==============================] - 2s 30ms/step - loss: 2.1399 - accuracy: 0.3967 - val_loss: 1.1464 - val_accuracy: 0.3267
# Epoch 2/100
# 10/10 [==============================] - 0s 8ms/step - loss: 1.4129 - accuracy: 0.4833 - val_loss: 1.1402 - val_accuracy: 0.3200
# Epoch 3/100
# 10/10 [==============================] - 0s 8ms/step - loss: 1.1242 - accuracy: 0.5600 - val_loss: 1.1487 - val_accuracy: 0.3200
# Epoch 4/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.8722 - accuracy: 0.6600 - val_loss: 1.1604 - val_accuracy: 0.3200
# Epoch 5/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.7943 - accuracy: 0.6867 - val_loss: 1.1785 - val_accuracy: 0.3200
# Epoch 6/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.6903 - accuracy: 0.7267 - val_loss: 1.2032 - val_accuracy: 0.3200
# Epoch 7/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.7358 - accuracy: 0.7300 - val_loss: 1.2320 - val_accuracy: 0.3200
# Epoch 8/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.5510 - accuracy: 0.7867 - val_loss: 1.2664 - val_accuracy: 0.3200
# Epoch 9/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.5296 - accuracy: 0.7733 - val_loss: 1.3002 - val_accuracy: 0.3200
# Epoch 10/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.5284 - accuracy: 0.8067 - val_loss: 1.3390 - val_accuracy: 0.3200
# Epoch 11/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.5055 - accuracy: 0.7933 - val_loss: 1.3817 - val_accuracy: 0.3200
# Epoch 12/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.4614 - accuracy: 0.8400 - val_loss: 1.4272 - val_accuracy: 0.3200
# Epoch 13/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.4600 - accuracy: 0.8067 - val_loss: 1.4686 - val_accuracy: 0.3200
# Epoch 14/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.4566 - accuracy: 0.8400 - val_loss: 1.5042 - val_accuracy: 0.3200
# Epoch 15/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.4539 - accuracy: 0.8333 - val_loss: 1.5254 - val_accuracy: 0.3200
# Epoch 16/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.4949 - accuracy: 0.7967 - val_loss: 1.5582 - val_accuracy: 0.3200
# Epoch 17/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.3686 - accuracy: 0.8767 - val_loss: 1.5822 - val_accuracy: 0.3200
# Epoch 18/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.4047 - accuracy: 0.8667 - val_loss: 1.5844 - val_accuracy: 0.3200
# Epoch 19/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.3727 - accuracy: 0.8500 - val_loss: 1.5878 - val_accuracy: 0.3200
# Epoch 20/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.3779 - accuracy: 0.8867 - val_loss: 1.5955 - val_accuracy: 0.3200
# Epoch 21/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.3323 - accuracy: 0.8933 - val_loss: 1.5836 - val_accuracy: 0.3200
# Epoch 22/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.3494 - accuracy: 0.8767 - val_loss: 1.5508 - val_accuracy: 0.3200
# Epoch 23/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.4049 - accuracy: 0.8467 - val_loss: 1.5278 - val_accuracy: 0.3200
# Epoch 24/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.3206 - accuracy: 0.8867 - val_loss: 1.4839 - val_accuracy: 0.3200
# Epoch 25/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.3277 - accuracy: 0.9000 - val_loss: 1.4450 - val_accuracy: 0.3267
# Epoch 26/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.3492 - accuracy: 0.8833 - val_loss: 1.3776 - val_accuracy: 0.3333
# Epoch 27/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.3383 - accuracy: 0.8833 - val_loss: 1.3253 - val_accuracy: 0.3567
# Epoch 28/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.2720 - accuracy: 0.9167 - val_loss: 1.2720 - val_accuracy: 0.3633
# Epoch 29/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.2936 - accuracy: 0.9233 - val_loss: 1.1992 - val_accuracy: 0.3733
# Epoch 30/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.3066 - accuracy: 0.9100 - val_loss: 1.0859 - val_accuracy: 0.3867
# Epoch 31/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.2951 - accuracy: 0.8933 - val_loss: 0.9693 - val_accuracy: 0.4033
# Epoch 32/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.3068 - accuracy: 0.9167 - val_loss: 0.8323 - val_accuracy: 0.4900
# Epoch 33/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.3298 - accuracy: 0.8967 - val_loss: 0.7207 - val_accuracy: 0.7367
# Epoch 34/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.2737 - accuracy: 0.9200 - val_loss: 0.6532 - val_accuracy: 0.8167
# Epoch 35/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.2808 - accuracy: 0.9167 - val_loss: 0.5973 - val_accuracy: 0.8533
# Epoch 36/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.2558 - accuracy: 0.9333 - val_loss: 0.5330 - val_accuracy: 0.8667
# Epoch 37/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.2497 - accuracy: 0.9333 - val_loss: 0.4708 - val_accuracy: 0.8767
# Epoch 38/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.2566 - accuracy: 0.9367 - val_loss: 0.4141 - val_accuracy: 0.8967
# Epoch 39/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.2643 - accuracy: 0.9167 - val_loss: 0.3686 - val_accuracy: 0.9100
# Epoch 40/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.2861 - accuracy: 0.9000 - val_loss: 0.3363 - val_accuracy: 0.9200
# Epoch 41/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.2580 - accuracy: 0.9333 - val_loss: 0.3117 - val_accuracy: 0.9333
# Epoch 42/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.2667 - accuracy: 0.9167 - val_loss: 0.2781 - val_accuracy: 0.9400
# Epoch 43/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.2254 - accuracy: 0.9433 - val_loss: 0.2573 - val_accuracy: 0.9433
# Epoch 44/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.2262 - accuracy: 0.9367 - val_loss: 0.2372 - val_accuracy: 0.9467
# Epoch 45/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.2260 - accuracy: 0.9433 - val_loss: 0.2234 - val_accuracy: 0.9467
# Epoch 46/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.2432 - accuracy: 0.9233 - val_loss: 0.2195 - val_accuracy: 0.9433
# Epoch 47/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.2216 - accuracy: 0.9567 - val_loss: 0.2083 - val_accuracy: 0.9467
# Epoch 48/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.2034 - accuracy: 0.9600 - val_loss: 0.1943 - val_accuracy: 0.9567
# Epoch 49/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.2001 - accuracy: 0.9700 - val_loss: 0.1872 - val_accuracy: 0.9533
# Epoch 50/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.2523 - accuracy: 0.9200 - val_loss: 0.1794 - val_accuracy: 0.9633
# Epoch 51/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.2266 - accuracy: 0.9467 - val_loss: 0.1679 - val_accuracy: 0.9800
# Epoch 52/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.2028 - accuracy: 0.9533 - val_loss: 0.1610 - val_accuracy: 0.9800
# Epoch 53/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.2017 - accuracy: 0.9533 - val_loss: 0.1558 - val_accuracy: 0.9867
# Epoch 54/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.2220 - accuracy: 0.9433 - val_loss: 0.1511 - val_accuracy: 0.9867
# Epoch 55/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.2110 - accuracy: 0.9533 - val_loss: 0.1477 - val_accuracy: 0.9867
# Epoch 56/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.1886 - accuracy: 0.9633 - val_loss: 0.1441 - val_accuracy: 0.9900
# Epoch 57/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.2176 - accuracy: 0.9567 - val_loss: 0.1372 - val_accuracy: 0.9933
# Epoch 58/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.1864 - accuracy: 0.9567 - val_loss: 0.1323 - val_accuracy: 0.9933
# Epoch 59/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.2044 - accuracy: 0.9533 - val_loss: 0.1283 - val_accuracy: 0.9933
# Epoch 60/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.1800 - accuracy: 0.9733 - val_loss: 0.1247 - val_accuracy: 1.0000
# Epoch 61/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.1908 - accuracy: 0.9600 - val_loss: 0.1220 - val_accuracy: 1.0000
# Epoch 62/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.1810 - accuracy: 0.9700 - val_loss: 0.1189 - val_accuracy: 1.0000
# Epoch 63/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.1659 - accuracy: 0.9700 - val_loss: 0.1158 - val_accuracy: 1.0000
# Epoch 64/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.1848 - accuracy: 0.9600 - val_loss: 0.1133 - val_accuracy: 1.0000
# Epoch 65/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.1494 - accuracy: 0.9800 - val_loss: 0.1113 - val_accuracy: 1.0000
# Epoch 66/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.1843 - accuracy: 0.9533 - val_loss: 0.1094 - val_accuracy: 1.0000
# Epoch 67/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.1557 - accuracy: 0.9767 - val_loss: 0.1085 - val_accuracy: 1.0000
# Epoch 68/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.1475 - accuracy: 0.9833 - val_loss: 0.1064 - val_accuracy: 1.0000
# Epoch 69/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.1685 - accuracy: 0.9733 - val_loss: 0.1039 - val_accuracy: 1.0000
# Epoch 70/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.1725 - accuracy: 0.9700 - val_loss: 0.1030 - val_accuracy: 1.0000
# Epoch 71/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.1437 - accuracy: 0.9900 - val_loss: 0.1012 - val_accuracy: 1.0000
# Epoch 72/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.1496 - accuracy: 0.9733 - val_loss: 0.0997 - val_accuracy: 1.0000
# Epoch 73/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.1645 - accuracy: 0.9633 - val_loss: 0.1004 - val_accuracy: 1.0000
# Epoch 74/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.1925 - accuracy: 0.9567 - val_loss: 0.0996 - val_accuracy: 1.0000
# Epoch 75/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.1634 - accuracy: 0.9667 - val_loss: 0.0981 - val_accuracy: 1.0000
# Epoch 76/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.1619 - accuracy: 0.9667 - val_loss: 0.0959 - val_accuracy: 1.0000
# Epoch 77/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.1502 - accuracy: 0.9767 - val_loss: 0.0957 - val_accuracy: 1.0000
# Epoch 78/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.1637 - accuracy: 0.9667 - val_loss: 0.0943 - val_accuracy: 1.0000
# Epoch 79/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.1463 - accuracy: 0.9867 - val_loss: 0.0932 - val_accuracy: 1.0000
# Epoch 80/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.1502 - accuracy: 0.9700 - val_loss: 0.0927 - val_accuracy: 1.0000
# Epoch 81/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.1329 - accuracy: 0.9800 - val_loss: 0.0925 - val_accuracy: 1.0000
# Epoch 82/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.1352 - accuracy: 0.9833 - val_loss: 0.0910 - val_accuracy: 1.0000
# Epoch 83/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.1529 - accuracy: 0.9833 - val_loss: 0.0890 - val_accuracy: 1.0000
# Epoch 84/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.1278 - accuracy: 0.9833 - val_loss: 0.0876 - val_accuracy: 1.0000
# Epoch 85/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.1372 - accuracy: 0.9867 - val_loss: 0.0875 - val_accuracy: 1.0000
# Epoch 86/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.1447 - accuracy: 0.9833 - val_loss: 0.0913 - val_accuracy: 1.0000
# Epoch 87/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.1231 - accuracy: 0.9933 - val_loss: 0.0906 - val_accuracy: 1.0000
# Epoch 88/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.1292 - accuracy: 0.9833 - val_loss: 0.0877 - val_accuracy: 1.0000
# Epoch 89/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.1346 - accuracy: 0.9833 - val_loss: 0.0851 - val_accuracy: 1.0000
# Epoch 90/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.1347 - accuracy: 0.9833 - val_loss: 0.0834 - val_accuracy: 1.0000
# Epoch 91/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.1312 - accuracy: 0.9800 - val_loss: 0.0819 - val_accuracy: 1.0000
# Epoch 92/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.1373 - accuracy: 0.9800 - val_loss: 0.0815 - val_accuracy: 1.0000
# Epoch 93/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.1169 - accuracy: 0.9933 - val_loss: 0.0815 - val_accuracy: 1.0000
# Epoch 94/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.1229 - accuracy: 0.9933 - val_loss: 0.0811 - val_accuracy: 1.0000
# Epoch 95/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.1336 - accuracy: 0.9800 - val_loss: 0.0812 - val_accuracy: 1.0000
# Epoch 96/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.1271 - accuracy: 0.9867 - val_loss: 0.0797 - val_accuracy: 1.0000
# Epoch 97/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.1163 - accuracy: 0.9833 - val_loss: 0.0786 - val_accuracy: 1.0000
# Epoch 98/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.1348 - accuracy: 0.9767 - val_loss: 0.0788 - val_accuracy: 1.0000
# Epoch 99/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.1287 - accuracy: 0.9833 - val_loss: 0.0787 - val_accuracy: 1.0000
# Epoch 100/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.1436 - accuracy: 0.9733 - val_loss: 0.0777 - val_accuracy: 1.0000

# %%
from explainability import LayerwiseRelevancePropagator


explainers = {
    encoder.categories_[0][i]: LayerwiseRelevancePropagator(model, layer=32, idx=i, alpha=2, beta=1) \
    for i in range(3)
}

# %%
for i in range(10):
    img = test_X[i]
    label = encoder.categories_[0][np.argmax(test_y[i])]

    fig, ax = plt.subplots(1, shape, figsize=(15, 2))
    fig.suptitle(f'Image {label}')
    for i in range(shape):
        ax[i].imshow(img[i], cmap='Greys_r')
        ax[i].axis('off')
    plt.show()

    for classname in encoder.categories_[0]:
        explanation = explainers[classname].predict(np.expand_dims(img, axis=0))
        explanation = explanation / np.amax(np.abs(explanation))

        fig, ax = plt.subplots(1, shape, figsize=(15, 2))
        fig.suptitle(f'{classname} explanation')
        for j in range(shape):
            ax[j].imshow(explanation[0,j], cmap='seismic', clim=(-1, 1))
            ax[j].axis('off')
        plt.show()

# %%
from scipy.spatial.distance import euclidean


labels = encoder.categories_[0]

square = np.zeros((16, 16, 16, 1))
square[4:12,4:12,4:12,0] = 1

fig, ax = plt.subplots(1, shape, figsize=(15, 2))
fig.suptitle('Square')
for j in range(shape):
    ax[j].imshow(square[j], cmap='Greys_r')
    ax[j].axis('off')
plt.show()

circle = np.zeros((16, 16, 16, 1))
center = (8, 8, 8)
radius = 4

for i in range(16):
    for j in range(16):
        for k in range(16):
            if euclidean((i, j, k), center) <= radius:
                circle[i,j,k,0] = 1
                
fig, ax = plt.subplots(1, shape, figsize=(15, 2))
fig.suptitle('Circle')
for j in range(shape):
    ax[j].imshow(circle[j], cmap='Greys_r')
    ax[j].axis('off')
plt.show()

combinations = [
    np.concatenate([square[:8], circle[8:]], axis=0),
    np.concatenate([circle[:8], square[8:]], axis=0),
    np.concatenate([square[:,:8], circle[:,8:]], axis=1),
    np.concatenate([circle[:,:8], square[:,8:]], axis=1),
    np.concatenate([square[:,:,:8], circle[:,:,8:]], axis=2),
    np.concatenate([circle[:,:,:8], square[:,:,8:]], axis=2),
]

for i in range(len(combinations)):
    fig, ax = plt.subplots(1, shape, figsize=(15, 2))
    prediction = model.predict(np.expand_dims(combinations[i], axis=0))[0]
    fig.suptitle(' '.join([f'{labels[i]}: {prediction[i]:.2f}' for i in range(len(labels))]))
    
    for j in range(shape):
        ax[j].imshow(combinations[i][j], cmap='Greys_r')
        ax[j].axis('off')
        
    plt.show()
        
    for j in range(3):
        fig, ax = plt.subplots(1, shape, figsize=(15, 2))
        classname = encoder.categories_[0][j]
        explanation = explainers[classname].predict(np.expand_dims(combinations[i], axis=0))[0]
        explanation = explanation / np.amax(np.abs(explanation))
        fig.suptitle(f'{classname} explanation')
        
        for k in range(shape):
            ax[k].imshow(explanation[k], cmap='seismic', clim=(-1, 1))
            ax[k].axis('off')
            
        plt.show()
        
    square_explanation = explainers['square'].predict(np.expand_dims(combinations[i], axis=0))[0]
    square_explanation = square_explanation - np.amin(square_explanation)
    square_explanation = square_explanation / np.amax(square_explanation)
    circle_explanation = explainers['circle'].predict(np.expand_dims(combinations[i], axis=0))[0]
    circle_explanation = circle_explanation - np.amin(circle_explanation)
    circle_explanation = circle_explanation / np.amax(circle_explanation)
    absolute_difference = square_explanation - circle_explanation
    
    fig, ax = plt.subplots(1, shape, figsize=(15, 2))
    fig.suptitle('Square explanation - circle explanation')

    for j in range(shape):
        ax[j].imshow(absolute_difference[j], cmap='seismic', clim=(-1, 1))
        ax[j].axis('off')

    plt.show()

# %%
print(len(model.layers))
