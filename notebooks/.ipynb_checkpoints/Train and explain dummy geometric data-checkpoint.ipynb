# %%
import matplotlib.pyplot as plt
import numpy as np

from sklearn.metrics.pairwise import euclidean_distances
from sklearn.preprocessing import OneHotEncoder
from typing import Tuple


np.random.seed(42)

def generate_square(shape: Tuple[int] = (16, 16, 16)) -> np.ndarray:
    img = np.zeros(shape)
    corner = np.asarray(shape) // 4 + np.random.randint(0, shape[0] // 2, 3)
    side = np.random.randint(shape[1] / 3, shape[1] * 2 / 3)
    
    idx = np.asarray(np.meshgrid(*[np.arange(side) for _ in range(3)])).T.reshape(-1, 3)
    idx += corner
    maxes = np.amax(idx, axis=-1)
    idx = idx[maxes < shape[0]]
    
    img[tuple(idx.T)] = 1
    
    return img

def generate_circle(shape: Tuple[int] = (16, 16, 16)) -> np.ndarray:
    img = np.zeros(shape)
    center = np.random.randint(0, shape[0], 3)
    radius = np.random.randint(shape[0] // 4, shape[0] // 2)

    idx = np.asarray(np.meshgrid(*[np.arange(x) for x in shape])).T.reshape(-1, 3)
    distances = euclidean_distances(idx, center.reshape(1, -1))[:,0]
    inside = distances <= radius
    
    img[tuple(idx[inside].T)] = 1
    
    return img

n = 200
shape = 16
squares = np.asarray([generate_square(shape=(shape, shape, shape)) for _ in range(n)])
circles = np.asarray([generate_circle(shape=(shape, shape, shape)) for _ in range(n)])
X = np.concatenate([squares, circles], axis=0)
y = np.asarray((['square'] * n) + (['circle'] * n))
idx = np.random.permutation(np.arange(len(X)))
X = np.reshape(X, (-1, shape, shape, shape, 1))
X = X[idx]
y = y[idx]

print(f'X.shape: {X.shape}')
print(f'y.shape: {y.shape}')

for i in range(10):
    fig, ax = plt.subplots(1, shape, figsize=(15, 2))
    fig.suptitle(y[i])
    for j in range(shape):
        ax[j].imshow(X[i,j], cmap='Greys_r')
        ax[j].axis('off')
    plt.show()

encoder = OneHotEncoder()
y = encoder.fit_transform(y.reshape(-1, 1)).toarray()

train_X = X[:300]
train_y = y[:300]
test_X = X[:300]
test_y = y[:300]
# Out:
# X.shape: (400, 16, 16, 16, 1)
# y.shape: (400,)

# %%
from tensorflow.keras import Model
from tensorflow.keras.layers import Activation, BatchNormalization, Conv3D, Dense, Dropout, \
                                    GlobalAveragePooling3D, Input, MaxPooling3D, Reshape
from tensorflow.keras.optimizers import Adam

input = Input((shape, shape, shape, 1))
x = input

x = Conv3D(8, (3, 3, 3), padding='SAME', activation=None)(x)
x = BatchNormalization()(x)
x = Activation('relu')(x)
x = MaxPooling3D((2, 2, 2))(x)

x = Conv3D(16, (3, 3, 3), padding='SAME', activation=None)(x)
x = BatchNormalization()(x)
x = Activation('relu')(x)
x = MaxPooling3D((2, 2, 2))(x)

x = Conv3D(32, (3, 3, 3), padding='SAME', activation=None)(x)
x = BatchNormalization()(x)
x = Activation('relu')(x)
x = MaxPooling3D((2, 2, 2))(x)

x = GlobalAveragePooling3D()(x)
x = Dropout(0.5)(x)
x = Dense(2, activation='softmax')(x)

model = Model(input, x)

model.compile(loss='categorical_crossentropy', optimizer=Adam(1e-4), metrics=['accuracy'])

model.fit(train_X, train_y, validation_data=(test_X, test_y), batch_size=32, epochs=100)
# Out:
# Epoch 1/100
# 10/10 [==============================] - 1s 22ms/step - loss: 1.4382 - accuracy: 0.5300 - val_loss: 0.6820 - val_accuracy: 0.4967
# Epoch 2/100
# 10/10 [==============================] - 0s 8ms/step - loss: 1.1588 - accuracy: 0.5200 - val_loss: 0.6768 - val_accuracy: 0.4967
# Epoch 3/100
# 10/10 [==============================] - 0s 8ms/step - loss: 1.0837 - accuracy: 0.5533 - val_loss: 0.6743 - val_accuracy: 0.4967
# Epoch 4/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.7700 - accuracy: 0.6167 - val_loss: 0.6741 - val_accuracy: 0.4967
# Epoch 5/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.7656 - accuracy: 0.6433 - val_loss: 0.6761 - val_accuracy: 0.4967
# Epoch 6/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.7459 - accuracy: 0.6767 - val_loss: 0.6786 - val_accuracy: 0.4967
# Epoch 7/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.7188 - accuracy: 0.6800 - val_loss: 0.6811 - val_accuracy: 0.4967
# Epoch 8/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.7053 - accuracy: 0.7000 - val_loss: 0.6819 - val_accuracy: 0.4967
# Epoch 9/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.6349 - accuracy: 0.6867 - val_loss: 0.6780 - val_accuracy: 0.4967
# Epoch 10/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.5891 - accuracy: 0.7200 - val_loss: 0.6691 - val_accuracy: 0.4967
# Epoch 11/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.5208 - accuracy: 0.7533 - val_loss: 0.6570 - val_accuracy: 0.4967
# Epoch 12/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.4813 - accuracy: 0.7733 - val_loss: 0.6436 - val_accuracy: 0.5033
# Epoch 13/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.5006 - accuracy: 0.7733 - val_loss: 0.6278 - val_accuracy: 0.5100
# Epoch 14/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.4596 - accuracy: 0.7900 - val_loss: 0.6086 - val_accuracy: 0.5467
# Epoch 15/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.4550 - accuracy: 0.7933 - val_loss: 0.5908 - val_accuracy: 0.6400
# Epoch 16/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.4140 - accuracy: 0.8433 - val_loss: 0.5743 - val_accuracy: 0.7400
# Epoch 17/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.3991 - accuracy: 0.8233 - val_loss: 0.5614 - val_accuracy: 0.7867
# Epoch 18/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.3820 - accuracy: 0.8333 - val_loss: 0.5489 - val_accuracy: 0.8367
# Epoch 19/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.4069 - accuracy: 0.8033 - val_loss: 0.5367 - val_accuracy: 0.8633
# Epoch 20/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.2774 - accuracy: 0.8700 - val_loss: 0.5336 - val_accuracy: 0.8533
# Epoch 21/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.2961 - accuracy: 0.8633 - val_loss: 0.5287 - val_accuracy: 0.8333
# Epoch 22/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.1789 - accuracy: 0.9467 - val_loss: 0.5248 - val_accuracy: 0.8067
# Epoch 23/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.2393 - accuracy: 0.9033 - val_loss: 0.5327 - val_accuracy: 0.7800
# Epoch 24/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.2475 - accuracy: 0.8733 - val_loss: 0.5437 - val_accuracy: 0.7400
# Epoch 25/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.2059 - accuracy: 0.9100 - val_loss: 0.5484 - val_accuracy: 0.7167
# Epoch 26/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.1856 - accuracy: 0.9333 - val_loss: 0.5642 - val_accuracy: 0.6833
# Epoch 27/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.1980 - accuracy: 0.9200 - val_loss: 0.6133 - val_accuracy: 0.6200
# Epoch 28/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.1640 - accuracy: 0.9300 - val_loss: 0.6531 - val_accuracy: 0.5800
# Epoch 29/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.1664 - accuracy: 0.9233 - val_loss: 0.6937 - val_accuracy: 0.5567
# Epoch 30/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.1470 - accuracy: 0.9433 - val_loss: 0.7501 - val_accuracy: 0.5433
# Epoch 31/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.1142 - accuracy: 0.9500 - val_loss: 0.7711 - val_accuracy: 0.5367
# Epoch 32/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.1166 - accuracy: 0.9633 - val_loss: 0.7623 - val_accuracy: 0.5500
# Epoch 33/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.1195 - accuracy: 0.9533 - val_loss: 0.6954 - val_accuracy: 0.5800
# Epoch 34/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.1034 - accuracy: 0.9633 - val_loss: 0.6856 - val_accuracy: 0.5800
# Epoch 35/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.1133 - accuracy: 0.9633 - val_loss: 0.6870 - val_accuracy: 0.5733
# Epoch 36/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0865 - accuracy: 0.9800 - val_loss: 0.7163 - val_accuracy: 0.5533
# Epoch 37/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0819 - accuracy: 0.9700 - val_loss: 0.7408 - val_accuracy: 0.5433
# Epoch 38/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0860 - accuracy: 0.9733 - val_loss: 0.7055 - val_accuracy: 0.5633
# Epoch 39/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0836 - accuracy: 0.9633 - val_loss: 0.7286 - val_accuracy: 0.5533
# Epoch 40/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0730 - accuracy: 0.9800 - val_loss: 0.7492 - val_accuracy: 0.5533
# Epoch 41/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0793 - accuracy: 0.9833 - val_loss: 0.7465 - val_accuracy: 0.5733
# Epoch 42/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0623 - accuracy: 0.9867 - val_loss: 0.7090 - val_accuracy: 0.6033
# Epoch 43/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0602 - accuracy: 0.9900 - val_loss: 0.6831 - val_accuracy: 0.6233
# Epoch 44/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0597 - accuracy: 0.9867 - val_loss: 0.6273 - val_accuracy: 0.6633
# Epoch 45/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0702 - accuracy: 0.9733 - val_loss: 0.5416 - val_accuracy: 0.7100
# Epoch 46/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0697 - accuracy: 0.9900 - val_loss: 0.5233 - val_accuracy: 0.7167
# Epoch 47/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0648 - accuracy: 0.9900 - val_loss: 0.4386 - val_accuracy: 0.7700
# Epoch 48/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0617 - accuracy: 0.9900 - val_loss: 0.3485 - val_accuracy: 0.8333
# Epoch 49/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0650 - accuracy: 0.9800 - val_loss: 0.3066 - val_accuracy: 0.8667
# Epoch 50/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0467 - accuracy: 0.9900 - val_loss: 0.3729 - val_accuracy: 0.8167
# Epoch 51/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0429 - accuracy: 0.9967 - val_loss: 0.3881 - val_accuracy: 0.8100
# Epoch 52/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0635 - accuracy: 0.9967 - val_loss: 0.3255 - val_accuracy: 0.8533
# Epoch 53/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0459 - accuracy: 0.9967 - val_loss: 0.2166 - val_accuracy: 0.9100
# Epoch 54/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0447 - accuracy: 0.9933 - val_loss: 0.2029 - val_accuracy: 0.9133
# Epoch 55/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0370 - accuracy: 0.9967 - val_loss: 0.1817 - val_accuracy: 0.9267
# Epoch 56/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0363 - accuracy: 0.9967 - val_loss: 0.1647 - val_accuracy: 0.9367
# Epoch 57/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0374 - accuracy: 0.9967 - val_loss: 0.1436 - val_accuracy: 0.9500
# Epoch 58/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0483 - accuracy: 0.9833 - val_loss: 0.1156 - val_accuracy: 0.9633
# Epoch 59/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0540 - accuracy: 0.9867 - val_loss: 0.0946 - val_accuracy: 0.9700
# Epoch 60/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0357 - accuracy: 1.0000 - val_loss: 0.1058 - val_accuracy: 0.9667
# Epoch 61/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0373 - accuracy: 0.9967 - val_loss: 0.0827 - val_accuracy: 0.9733
# Epoch 62/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0439 - accuracy: 0.9967 - val_loss: 0.0495 - val_accuracy: 0.9900
# Epoch 63/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0341 - accuracy: 0.9933 - val_loss: 0.0392 - val_accuracy: 0.9967
# Epoch 64/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0451 - accuracy: 0.9833 - val_loss: 0.0331 - val_accuracy: 0.9967
# Epoch 65/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0278 - accuracy: 1.0000 - val_loss: 0.0280 - val_accuracy: 0.9967
# Epoch 66/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0381 - accuracy: 0.9933 - val_loss: 0.0239 - val_accuracy: 0.9967
# Epoch 67/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0317 - accuracy: 0.9933 - val_loss: 0.0202 - val_accuracy: 0.9967
# Epoch 68/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0333 - accuracy: 0.9933 - val_loss: 0.0197 - val_accuracy: 0.9967
# Epoch 69/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0430 - accuracy: 0.9900 - val_loss: 0.0201 - val_accuracy: 0.9967
# Epoch 70/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0377 - accuracy: 0.9967 - val_loss: 0.0213 - val_accuracy: 0.9967
# Epoch 71/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0324 - accuracy: 0.9933 - val_loss: 0.0161 - val_accuracy: 1.0000
# Epoch 72/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0306 - accuracy: 0.9967 - val_loss: 0.0155 - val_accuracy: 1.0000
# Epoch 73/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0276 - accuracy: 1.0000 - val_loss: 0.0153 - val_accuracy: 1.0000
# Epoch 74/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0323 - accuracy: 0.9933 - val_loss: 0.0144 - val_accuracy: 1.0000
# Epoch 75/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0283 - accuracy: 0.9967 - val_loss: 0.0139 - val_accuracy: 1.0000
# Epoch 76/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0249 - accuracy: 1.0000 - val_loss: 0.0163 - val_accuracy: 1.0000
# Epoch 77/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0400 - accuracy: 0.9967 - val_loss: 0.0157 - val_accuracy: 1.0000
# Epoch 78/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0220 - accuracy: 0.9967 - val_loss: 0.0133 - val_accuracy: 1.0000
# Epoch 79/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0234 - accuracy: 1.0000 - val_loss: 0.0114 - val_accuracy: 1.0000
# Epoch 80/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0296 - accuracy: 0.9933 - val_loss: 0.0120 - val_accuracy: 1.0000
# Epoch 81/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0282 - accuracy: 0.9967 - val_loss: 0.0109 - val_accuracy: 1.0000
# Epoch 82/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0292 - accuracy: 0.9967 - val_loss: 0.0101 - val_accuracy: 1.0000
# Epoch 83/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0337 - accuracy: 0.9900 - val_loss: 0.0089 - val_accuracy: 1.0000
# Epoch 84/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0280 - accuracy: 0.9967 - val_loss: 0.0085 - val_accuracy: 1.0000
# Epoch 85/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0315 - accuracy: 0.9967 - val_loss: 0.0080 - val_accuracy: 1.0000
# Epoch 86/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0252 - accuracy: 1.0000 - val_loss: 0.0077 - val_accuracy: 1.0000
# Epoch 87/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0156 - accuracy: 1.0000 - val_loss: 0.0075 - val_accuracy: 1.0000
# Epoch 88/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0187 - accuracy: 1.0000 - val_loss: 0.0072 - val_accuracy: 1.0000
# Epoch 89/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0189 - accuracy: 1.0000 - val_loss: 0.0071 - val_accuracy: 1.0000
# Epoch 90/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0249 - accuracy: 0.9967 - val_loss: 0.0070 - val_accuracy: 1.0000
# Epoch 91/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0168 - accuracy: 1.0000 - val_loss: 0.0072 - val_accuracy: 1.0000
# Epoch 92/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0199 - accuracy: 1.0000 - val_loss: 0.0071 - val_accuracy: 1.0000
# Epoch 93/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0222 - accuracy: 1.0000 - val_loss: 0.0067 - val_accuracy: 1.0000
# Epoch 94/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0294 - accuracy: 0.9967 - val_loss: 0.0065 - val_accuracy: 1.0000
# Epoch 95/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0184 - accuracy: 1.0000 - val_loss: 0.0064 - val_accuracy: 1.0000
# Epoch 96/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0174 - accuracy: 1.0000 - val_loss: 0.0063 - val_accuracy: 1.0000
# Epoch 97/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0343 - accuracy: 0.9933 - val_loss: 0.0061 - val_accuracy: 1.0000
# Epoch 98/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0190 - accuracy: 0.9967 - val_loss: 0.0063 - val_accuracy: 1.0000
# Epoch 99/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0254 - accuracy: 0.9967 - val_loss: 0.0062 - val_accuracy: 1.0000
# Epoch 100/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0184 - accuracy: 1.0000 - val_loss: 0.0060 - val_accuracy: 1.0000

# %%
from explainability import LayerwiseRelevancePropagator


explainers = {
    encoder.categories_[0][0]: LayerwiseRelevancePropagator(model, layer=17, idx=0, alpha=2, beta=1),
    encoder.categories_[0][1]: LayerwiseRelevancePropagator(model, layer=17, idx=1, alpha=2, beta=1)
}

# %%
img = test_X[0]
label = encoder.categories_[0][np.argmax(test_y[0])]

fig, ax = plt.subplots(1, shape, figsize=(15, 2))
fig.suptitle(f'Image {label}')
for i in range(shape):
    ax[i].imshow(img[i], cmap='Greys_r')
    ax[i].axis('off')
plt.show()

print(img.shape)
model.predict(test_X[:32])

for label in ['square', 'circle']:
    explanation = explainers[label].predict(test_X[:1])
# Out:
# (16, 16, 16, 1)

# %%
explainers['square'].summary()
# Out:
# Model: "layerwise_relevance_propagator_2"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_13 (InputLayer)           [(None, 16, 16, 16)] 0
# __________________________________________________________________________________________________
# reshape_12 (Reshape)            (None, 16, 16, 16, 1 0           input_13[0][0]
# __________________________________________________________________________________________________
# conv3d_30 (Conv3D)              (None, 16, 16, 16, 8 224         reshape_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_30 (BatchNo (None, 16, 16, 16, 8 32          conv3d_30[0][0]
# __________________________________________________________________________________________________
# activation_30 (Activation)      (None, 16, 16, 16, 8 0           batch_normalization_30[0][0]
# __________________________________________________________________________________________________
# max_pooling3d_30 (MaxPooling3D) (None, 8, 8, 8, 8)   0           activation_30[0][0]
# __________________________________________________________________________________________________
# conv3d_31 (Conv3D)              (None, 8, 8, 8, 16)  3472        max_pooling3d_30[0][0]
# __________________________________________________________________________________________________
# batch_normalization_31 (BatchNo (None, 8, 8, 8, 16)  64          conv3d_31[0][0]
# __________________________________________________________________________________________________
# activation_31 (Activation)      (None, 8, 8, 8, 16)  0           batch_normalization_31[0][0]
# __________________________________________________________________________________________________
# max_pooling3d_31 (MaxPooling3D) (None, 4, 4, 4, 16)  0           activation_31[0][0]
# __________________________________________________________________________________________________
# conv3d_32 (Conv3D)              (None, 4, 4, 4, 32)  13856       max_pooling3d_31[0][0]
# __________________________________________________________________________________________________
# batch_normalization_32 (BatchNo (None, 4, 4, 4, 32)  128         conv3d_32[0][0]
# __________________________________________________________________________________________________
# activation_32 (Activation)      (None, 4, 4, 4, 32)  0           batch_normalization_32[0][0]
# __________________________________________________________________________________________________
# max_pooling3d_32 (MaxPooling3D) (None, 2, 2, 2, 32)  0           activation_32[0][0]
# __________________________________________________________________________________________________
# global_average_pooling3d_10 (Gl (None, 32)           0           max_pooling3d_32[0][0]
# __________________________________________________________________________________________________
# dropout_9 (Dropout)             (None, 32)           0           global_average_pooling3d_10[0][0]
# __________________________________________________________________________________________________
# dense_9 (Dense)                 (None, 2)            66          dropout_9[0][0]
# __________________________________________________________________________________________________
# tf.zeros_like_2 (TFOpLambda)    (None, 2)            0           dense_9[0][0]
# __________________________________________________________________________________________________
# tf.where_2 (TFOpLambda)         (None, 2)            0           dense_9[0][0]
#                                                                  tf.zeros_like_2[0][0]
# __________________________________________________________________________________________________
# 16 (DenseLRP)                   (None, 32)           66          dropout_9[0][0]
#                                                                  tf.where_2[0][0]
# __________________________________________________________________________________________________
# 15 (NoOpLRP)                    (None, 32)           0           global_average_pooling3d_10[0][0]
#                                                                  16[0][0]
# __________________________________________________________________________________________________
# 14 (AveragePoolingLRP)          (None, 2, 2, 2, 32)  0           max_pooling3d_32[0][0]
#                                                                  15[0][0]
# __________________________________________________________________________________________________
# 13 (MaxPoolingLRP)              (None, 4, 4, 4, 32)  0           activation_32[0][0]
#                                                                  14[0][0]
# __________________________________________________________________________________________________
# 12 (ReLULRP)                    (None, 4, 4, 4, 32)  0           batch_normalization_32[0][0]
#                                                                  13[0][0]
# __________________________________________________________________________________________________
# 11 (NoOpLRP)                    (None, 4, 4, 4, 32)  128         conv3d_32[0][0]
#                                                                  12[0][0]
# __________________________________________________________________________________________________
# 10 (Conv3DLRP)                  (None, 4, 4, 4, 16)  13856       max_pooling3d_31[0][0]
#                                                                  11[0][0]
# __________________________________________________________________________________________________
# 9 (MaxPoolingLRP)               (None, 8, 8, 8, 16)  0           activation_31[0][0]
#                                                                  10[0][0]
# __________________________________________________________________________________________________
# 8 (ReLULRP)                     (None, 8, 8, 8, 16)  0           batch_normalization_31[0][0]
#                                                                  9[0][0]
# __________________________________________________________________________________________________
# 7 (NoOpLRP)                     (None, 8, 8, 8, 16)  64          conv3d_31[0][0]
#                                                                  8[0][0]
# __________________________________________________________________________________________________
# 6 (Conv3DLRP)                   (None, 8, 8, 8, 8)   3472        max_pooling3d_30[0][0]
#                                                                  7[0][0]
# __________________________________________________________________________________________________
# 5 (MaxPoolingLRP)               (None, 16, 16, 16, 8 0           activation_30[0][0]
#                                                                  6[0][0]
# __________________________________________________________________________________________________
# 4 (ReLULRP)                     (None, 16, 16, 16, 8 0           batch_normalization_30[0][0]
#                                                                  5[0][0]
# __________________________________________________________________________________________________
# 3 (NoOpLRP)                     (None, 16, 16, 16, 8 32          conv3d_30[0][0]
#                                                                  4[0][0]
# __________________________________________________________________________________________________
# 2 (Conv3DLRP)                   (None, 16, 16, 16, 1 224         reshape_12[0][0]
#                                                                  3[0][0]
# __________________________________________________________________________________________________
# 1 (ReshapeLRP)                  (None, 16, 16, 16)   0           input_13[0][0]
#                                                                  2[0][0]
# ==================================================================================================
# Total params: 35,572
# Trainable params: 17,730
# Non-trainable params: 17,842
# __________________________________________________________________________________________________
